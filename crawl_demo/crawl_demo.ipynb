# %%
import requests

# %%
response=requests.get('http://ip.zdaye.com/dayProxy/2018//12/1.html')
response.text
# Out:
# '\r\n<!DOCTYPE html>\r\n<html lang=\'zh-CN\'>\r\n<head>\r\n<meta charset=\'gb2312\'>\r\n<meta content=\'IE=edge\' http-equiv=\'X-UA-Compatible\'>\r\n<title>2018Äê12ÔÂ Ã¿ÈÕÃâ·Ñ´úÀíIP - Õ¾´óÒ¯ - ÆóÒµ¼¶¸ßÆ·ÖÊHttp´úÀíIP/Socks5´úÀíIP¹©Ó¦Æ½Ì¨/Ãâ·Ñ´úÀíIP</title>\r\n<script src="/js/ice.js"></script>\r\n<script src="/js/jquery.min.js"></script>\r\n\r\n<script src="/js/gt.js"></script>\r\n<link href="/css/ice.css" media="all" rel="stylesheet" />\r\n<link href="/css/zzsc.css" rel="stylesheet" type="text/css">\r\n<link href="/img/favicon.ico" rel="shortcut icon" type="image/vnd.microsoft.icon" />\r\n<meta name="keywords" content="´úÀíIP,Ãâ·Ñ´úÀíIP,×îÐÂ´úÀíIP,Õ¾´óÒ¯,Ò»ÊÖË½ÃÜ´úÀíIP,ÎåÎ»Ëæ»ú´úÀíIP,HTTP´úÀíIP,Socks5´úÀíIP,S5´úÀíIP">\r\n<meta name="description" content="Õ¾´óÒ¯ÊÇÒ»¼Ò×¨ÒµµÄÆóÒµ¼¶¸ßÖÊÁ¿´úÀíIP¹©Ó¦Æ½Ì¨£¬ÔÚÕâÀïÓÐ¸÷ÖÖ¸ßÖÊÁ¿µÄHTTP´úÀíIPºÍSocks5´úÀíIP£¬ÇÒ³£ÄêÌá¹©Ãâ·Ñ´úÀíIPÎª¼¼Êõ°®ºÃÕßÃâ·ÑÑ§Ï°´úÀíIPÖªÊ¶ËùÓÃ£»Õ¾´óÒ¯´úÀíIPÊÇÄú·¢Õ¹ÅÀ³æ¡¢´óÊý¾ÝÊÂÒµµÄºÃ°ïÊÖ£¡">\r\n<meta content=\'width=device-widt
# ...
