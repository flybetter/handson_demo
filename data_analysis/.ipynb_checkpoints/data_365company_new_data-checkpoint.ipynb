# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('demo.csv')

# %%
df
# Out:
#            id    app app_version  platform  os_version model_type  \
# 0   696809464  365淘房      8.0.10        22        12.1  Simulator
# 1   696811067  365淘房      8.0.10        22        12.1  Simulator
# 2   696811068  365淘房      8.0.10        22        12.1  Simulator
# 3   696814168  365淘房      8.0.10        22        12.1  Simulator
# 4   696814170  365淘房      8.0.10        22        12.1  Simulator
# 5   696814172  365淘房      8.0.10        22        12.1  Simulator
# 6   696814173  365淘房      8.0.10        22        12.1  Simulator
# 7   696814174  365淘房      8.0.10        22        12.1  Simulator
# 8   696814175  365淘房      8.0.10        22        12.1  Simulator
# 9   696814176  365淘房      8.0.10        22        12.1  Simulator
# 10  696814177  365淘房      8.0.10        22        12.1  Simulator
# 11  696814178  365淘房      8.0.10        22        12.1  Simulator
# 12  696814180  365淘房      8.0.10        22        12.1  Simulator
# 13  696814183  365淘房      8.0.10        22        12.1  Simulator
# 14  696814214  365淘房      8.0.10        22        12.1  Simulator
# 15  696814265  365淘房      8.0.10        22        12.1  Simulator
# 16  696814300  365淘房      8.0.10        22        12.1  Simulator
# 17  696814329  365淘房      8.0.10        22        12.1  Simulator
# 18  696815694  365淘房      8.0.10        22        12.1  Simulator
# 19  696815699  365淘房      8.0.10        22        12.1  Simulator
# 20  696815700  365淘房      8.0.10        22        12.1  Simulator
# 21  696815703  365淘房      8.0.10        22        12.1  Simulator
# 22  696815707  365淘房      8.0.10        22        12.1  Simulator
# 23  696815709  365淘房      8.0.10        22        12.1  Simulator
# 24  696815715  365淘房      8.0.10        22        12.1  Simulator
# 25  696815745  365淘房      8.0.10        22        12.1  Simulator
# 26  696815780  365淘房      8.0.10        22        12.1  Simulator
#
#                                device_id    channel  \
# 0   443048C5-1ECA-4285-9257-33C45C131FC0  App Store
# 1   443048C5-1ECA-4285-9257-33C45C131FC0  App Store
# 2   443048C5-1ECA-4285-9257-33C45C131FC0  App Store
# 3   443048C5-1ECA-4285-9257-33C45C131FC0  App Store
# 4   443048C5-1ECA-4285-9257-33C45C131FC0  App Store
# 5   443048C5-1ECA-4285-9257-33C45C131FC0  App Store
# 6   443048C5-1ECA-4285-9257-33C45C131FC0  App Store
# 7   443048C5-1ECA-4285-9257-33C45C131FC0  App Store
# 8   443048C5-1ECA-4285-9257-33C45C131FC0  App Store
# 9   443048C5-1ECA-4285-9257-33C45C131FC0  App Store
# 10  443048C5-1ECA-4285-9257-33C45C131FC0  App Store
# 11  443048C5-1ECA-4285-9257-33C45C131FC0  App Store
# 12  443048C5-1ECA-4285-9257-33C45C131FC0  App Store
# 13  443048C5-1ECA-4285-9257-33C45C131FC0  App Store
# 14  443048C5-1ECA-4285-9257-33C45C131FC0  App Store
# 15  443048C5-1ECA-4285-9257-33C45C131FC0  App Store
# 16  443048C5-1ECA-4285-9257-33C45C131FC0  App Store
# 17  443048C5-1ECA-4285-9257-33C45C131FC0  App Store
# 18  443048C5-1ECA-4285-9257-33C45C131FC0  App Store
# 19  443048C5-1ECA-4285-9257-33C45C131FC0  App Store
# 20  443048C5-1ECA-4285-9257-33C45C131FC0  App Store
# 21  443048C5-1ECA-4285-9257-33C45C131FC0  App Store
# 22  443048C5-1ECA-4285-9257-33C45C131FC0  App Store
# 23  443048C5-1ECA-4285-9257-33C45C131FC0  App Store
# 24  443048C5-1ECA-4285-9257-33C45C131FC0  App Store
# 25  443048C5-1ECA-4285-9257-33C45C131FC0  App Store
# 26  443048C5-1ECA-4285-9257-33C45C131FC0  App Store
#
#                         user_ip                            session_id  \
# 0   218.94.115.131, 172.17.1.60  1D006168-C7B3-4371-861F-5C334599F7B5
# 1   218.94.115.131, 172.17.1.59  1D006168-C7B3-4371-861F-5C334599F7B5
# 2   218.94.115.131, 172.17.1.59  1D006168-C7B3-4371-861F-5C334599F7B5
# 3   218.94.115.131, 172.17.1.60  1D006168-C7B3-4371-861F-5C334599F7B5
# 4   218.94.115.131, 172.17.1.60  1D006168-C7B3-4371-861F-5C334599F7B5
# 5   218.94.115.131, 172.17.1.60  1D006168-C7B3-4371-861F-5C334599F7B5
# 6   218.94.115.131, 172.17.1.60  1D006168-C7B3-4371-861F-5C334599F7B5
# 7   218.94.115.131, 172.17.1.60  1D006168-C7B3-4371-861F-5C334599F7B5
# 8   218.94.115.131, 172.17.1.60  1D006168-C7B3-4371-861F-5C334599F7B5
# 9   218.94.115.131, 172.17.1.60  1D006168-C7B3-4371-861F-5C334599F7B5
# 10  218.94.115.131, 172.17.1.60  1D006168-C7B3-4371-861F-5C334599F7B5
# 11  218.94.115.131, 172.17.1.60  1D006168-C7B3-4371-861F-5C334599F7B5
# 12  218.94.115.131, 172.17.1.60  1D006168-C7B3-4371-861F-5C334599F7B5
# 13  218.94.115.131, 172.17.1.60  1D006168-C7B3-4371-861F-5C334599F7B5
# 14  218.94.115.131, 172.17.1.60  1D006168-C7B3-4371-861F-5C334599F7B5
# 15  218.94.115.131, 172.17.1.60  1D006168-C7B3-4371-861F-5C334599F7B5
# 16  218.94.115.131, 172.17.1.60  1D006168-C7B3-4371-861F-5C334599F7B5
# 17  218.94.115.131, 172.17.1.60  1D006168-C7B3-4371-861F-5C334599F7B5
# 18  218.94.115.131, 172.17.1.60  1D006168-C7B3-4371-861F-5C334599F7B5
# 19  218.94.115.131, 172.17.1.60  1D006168-C7B3-4371-861F-5C334599F7B5
# 20  218.94.115.131, 172.17.1.60  1D006168-C7B3-4371-861F-5C334599F7B5
# 21  218.94.115.131, 172.17.1.60  1D006168-C7B3-4371-861F-5C334599F7B5
# 22  218.94.115.131, 172.17.1.60  1D006168-C7B3-4371-861F-5C334599F7B5
# 23  218.94.115.131, 172.17.1.60  1D006168-C7B3-4371-861F-5C334599F7B5
# 24  218.94.115.131, 172.17.1.60  1D006168-C7B3-4371-861F-5C334599F7B5
# 25  218.94.115.131, 172.17.1.60  1D006168-C7B3-4371-861F-5C334599F7B5
# 26  218.94.115.131, 172.17.1.60  1D006168-C7B3-4371-861F-5C334599F7B5
#
#                           ...                                     end_time  \
# 0                         ...                                          NaN
# 1                         ...                                          NaN
# 2                         ...                          2018-12-24 16:01:33
# 3                         ...                                          NaN
# 4                         ...                                          NaN
# 5                         ...                                          NaN
# 6                         ...                                          NaN
# 7                         ...                                          NaN
# 8                         ...                                          NaN
# 9                         ...                                          NaN
# 10                        ...                                          NaN
# 11                        ...                                          NaN
# 12                        ...                                          NaN
# 13                        ...                                          NaN
# 14                        ...                          2018-12-24 16:02:27
# 15                        ...                                          NaN
# 16                        ...                                          NaN
# 17                        ...                                          NaN
# 18                        ...                          2018-12-24 16:02:36
# 19                        ...                          2018-12-24 16:02:34
# 20                        ...                                          NaN
# 21                        ...                          2018-12-24 16:02:36
# 22                        ...                                          NaN
# 23                        ...                          2018-12-24 16:02:44
# 24                        ...                          2018-12-24 16:02:36
# 25                        ...                                          NaN
# 26                        ...                          2018-12-24 16:02:42
#
#    pagination target_page_id  code_channel  account_name search_key  \
# 0         NaN            NaN           NaN           NaN        NaN
# 1         NaN            NaN           NaN           NaN        NaN
# 2         NaN            NaN           NaN           NaN        NaN
# 3         NaN            NaN           NaN           NaN        NaN
# 4         NaN            NaN           NaN           NaN        NaN
# 5         NaN            NaN           NaN           NaN        NaN
# 6         NaN            NaN           NaN           NaN        NaN
# 7         NaN            NaN           NaN           NaN        NaN
# 8         NaN            NaN           NaN           NaN        NaN
# 9         NaN            NaN           NaN           NaN        NaN
# 10        NaN            NaN           NaN           NaN        NaN
# 11        NaN            NaN           NaN           NaN        NaN
# 12        NaN            NaN           NaN           NaN        NaN
# 13        NaN            NaN           NaN           NaN        NaN
# 14        1.0            NaN           NaN           NaN        NaN
# 15        NaN            NaN           NaN           NaN        NaN
# 16        NaN            NaN           NaN           NaN        NaN
# 17        NaN            NaN           NaN           NaN        NaN
# 18        2.0            NaN           NaN           NaN        NaN
# 19        5.0            NaN           NaN           NaN        NaN
# 20        NaN            NaN           NaN           NaN        NaN
# 21        4.0            NaN           NaN           NaN        NaN
# 22        NaN            NaN           NaN           NaN        NaN
# 23        7.0            NaN           NaN           NaN        NaN
# 24        3.0            NaN           NaN           NaN        NaN
# 25        NaN            NaN           NaN           NaN        NaN
# 26        6.0            NaN           NaN           NaN        NaN
#
#    search_type event_type context_id  \
# 0          NaN          8        NaN
# 1          NaN          3        NaN
# 2          NaN         17        NaN
# 3          NaN          4        NaN
# 4          NaN          3        NaN
# 5          NaN          3   1-234015
# 6          NaN          3   1-234015
# 7          NaN          3   1-234015
# 8          NaN          3   1-234015
# 9          NaN          3   1-234015
# 10         NaN          3   1-234015
# 11         NaN          4        NaN
# 12         NaN          4        NaN
# 13         NaN          3        NaN
# 14         NaN          2        NaN
# 15         NaN          3        NaN
# 16         NaN          3        NaN
# 17         NaN          3        NaN
# 18         NaN          2   1-234015
# 19         NaN          2        NaN
# 20         NaN          4        NaN
# 21         NaN          2        NaN
# 22         NaN          4        NaN
# 23         NaN          2        NaN
# 24         NaN          2        NaN
# 25         NaN          4        NaN
# 26         NaN          2        NaN
#
#                                               content
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18  {\n  "projectType" : "1",\n  "projectId" : "23...
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23  {\n  "roomId" : "6688502",\n  "projectType" : ...
# 24                  {"shaiXuan":"筛选_类型_住宅_开盘时间_下月开盘"}
# 25                               3室2厅2卫 105㎡ 234015 1
# 26  {\n  "modelId" : "2580867",\n  "projectType" :...
#
# [27 rows x 41 columns]

# %%
from pandas.io.json import json_normalize

# %%
df['content']
# Out:
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# 5                                                   NaN
# 6                                                   NaN
# 7                                                   NaN
# 8                                                   NaN
# 9                                                   NaN
# 10                                                  NaN
# 11                                                  NaN
# 12                                                  NaN
# 13                                                  NaN
# 14                                                  NaN
# 15                                                  NaN
# 16                                                  NaN
# 17                                                  NaN
# 18    {\n  "projectType" : "1",\n  "projectId" : "23...
# 19                                                  NaN
# 20                                                  NaN
# 21                                                  NaN
# 22                                                  NaN
# 23    {\n  "roomId" : "6688502",\n  "projectType" : ...
# 24                    {"shaiXuan":"筛选_类型_住宅_开盘时间_下月开盘"}
# 25                                 3室2厅2卫 105㎡ 234015 1
# 26    {\n  "modelId" : "2580867",\n  "projectType" :...
# Name: content, dtype: object

# %%
# import json
# def custom(x):
#     try:
#         object=json.loads(x)
#         return (object['roomId'],object['projectType'],object['projectId'])
#     except:
#         return (np.NAN,np.NAN,np.NAN)
    
# (df['roomId'],df['projectType'],df['projectId'])=df['content'].apply(custom)

# %%
import json
def custom(df):
    try:
        object=json.loads(df['content'])
        df['roomId']=object.get('roomId',np.NaN)
        df['projectType']=object.get('projectType',np.NaN)
        df['modelId']=object.get('modelId',np.NaN)
        df['projectId']=object.get('projectId',np.NaN)
        df['shaiXuan']=object.get('shaiXuan',np.NaN)
        return df
    except:
        df['roomId']=np.NaN
        df['projectType']=np.NaN
        df['modelId']=np.NaN
        df['projectId']=np.NaN
        df['shaiXuan']=np.NaN
        return df
df=df.apply(custom,axis=1)

# %%
df.dropna(subset=['content'])
# Out:
#            id    app app_version  platform  os_version model_type  \
# 18  696815694  365淘房      8.0.10        22        12.1  Simulator
# 23  696815709  365淘房      8.0.10        22        12.1  Simulator
# 24  696815715  365淘房      8.0.10        22        12.1  Simulator
# 25  696815745  365淘房      8.0.10        22        12.1  Simulator
# 26  696815780  365淘房      8.0.10        22        12.1  Simulator
#
#                                device_id    channel  \
# 18  443048C5-1ECA-4285-9257-33C45C131FC0  App Store
# 23  443048C5-1ECA-4285-9257-33C45C131FC0  App Store
# 24  443048C5-1ECA-4285-9257-33C45C131FC0  App Store
# 25  443048C5-1ECA-4285-9257-33C45C131FC0  App Store
# 26  443048C5-1ECA-4285-9257-33C45C131FC0  App Store
#
#                         user_ip                            session_id  \
# 18  218.94.115.131, 172.17.1.60  1D006168-C7B3-4371-861F-5C334599F7B5
# 23  218.94.115.131, 172.17.1.60  1D006168-C7B3-4371-861F-5C334599F7B5
# 24  218.94.115.131, 172.17.1.60  1D006168-C7B3-4371-861F-5C334599F7B5
# 25  218.94.115.131, 172.17.1.60  1D006168-C7B3-4371-861F-5C334599F7B5
# 26  218.94.115.131, 172.17.1.60  1D006168-C7B3-4371-861F-5C334599F7B5
#
#            ...         search_key search_type event_type  context_id  \
# 18         ...                NaN         NaN          2    1-234015
# 23         ...                NaN         NaN          2         NaN
# 24         ...                NaN         NaN          2         NaN
# 25         ...                NaN         NaN          4         NaN
# 26         ...                NaN         NaN          2         NaN
#
#                                               content   roomId projectType  \
# 18  {\n  "projectType" : "1",\n  "projectId" : "23...      NaN           1
# 23  {\n  "roomId" : "6688502",\n  "projectType" : ...  6688502           1
# 24                  {"shaiXuan":"筛选_类型_住宅_开盘时间_下月开盘"}      NaN         NaN
# 25                               3室2厅2卫 105㎡ 234015 1      NaN         NaN
# 26  {\n  "modelId" : "2580867",\n  "projectType" :...      NaN           1
#
#     modelId projectId            shaiXuan
# 18      NaN    234015                 NaN
# 23      NaN    234015                 NaN
# 24      NaN       NaN  筛选_类型_住宅_开盘时间_下月开盘
# 25      NaN       NaN                 NaN
# 26  2580867    234015                 NaN
#
# [5 rows x 46 columns]

# %%
columns=[ 'PIC_ID','PIC_PRJID','PIC_PRJNAME','PIC_TYPE','PIC_DESC','PIC_TING','PIC_WEI','PIC_CHU','PIC_AREA','PIC_SELL_POINT','PIC_HX_TOTALPRICE' ]
df2=pd.read_csv('newHouseModel.txt', names=columns,header=None ,dtype={'PIC_ID':object})
# Out:
# /Users/michael/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (3,6,7,8,10) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df2[:10]
# Out:
#   PIC_ID  PIC_PRJID PIC_PRJNAME PIC_TYPE        PIC_DESC PIC_TING PIC_WEI  \
# 0      1          1      东恒阳光嘉园        3       a1 拷贝.jpg        0       0
# 1      2          1      东恒阳光嘉园        3       a2 拷贝.jpg        0       0
# 2      3          1      东恒阳光嘉园        3       a3 拷贝.jpg        0       0
# 3      4          1      东恒阳光嘉园        3       b1 拷贝.jpg        0       0
# 4      5          1      东恒阳光嘉园        3       b2 拷贝.jpg        0       0
# 5      6          1      东恒阳光嘉园        3       b3 拷贝.jpg        0       0
# 6      7          1      东恒阳光嘉园        3  C09-二层平面_w.jpg        0       0
# 7      8          1      东恒阳光嘉园        3       c1 拷贝.jpg        0       0
# 8      9          1      东恒阳光嘉园        3       c2 拷贝.jpg        0       0
# 9     10          1      东恒阳光嘉园        3       c3 拷贝.jpg        0       0
#
#   PIC_CHU PIC_AREA PIC_SELL_POINT PIC_HX_TOTALPRICE
# 0       0        0            NaN               NaN
# 1       0        0            NaN               NaN
# 2       0        0            NaN               NaN
# 3       0        0            NaN               NaN
# 4       0        0            NaN               NaN
# 5       0        0            NaN               NaN
# 6       0        0            NaN               NaN
# 7       0        0            NaN               NaN
# 8       0        0            NaN               NaN
# 9       0        0            NaN               NaN

# %%
df_model=df.merge(df2,left_on='modelId',right_on='PIC_ID',how='left')

# %%
df_model.dropna(subset=['PIC_PRJID'])
# Out:
#            id    app app_version  platform  os_version model_type  \
# 26  696815780  365淘房      8.0.10        22        12.1  Simulator
#
#                                device_id    channel  \
# 26  443048C5-1ECA-4285-9257-33C45C131FC0  App Store
#
#                         user_ip                            session_id  \
# 26  218.94.115.131, 172.17.1.60  1D006168-C7B3-4371-861F-5C334599F7B5
#
#           ...        PIC_PRJID PIC_PRJNAME PIC_TYPE    PIC_DESC  PIC_TING  \
# 26        ...         234015.0          熙悦       10  熙悦C户型图105㎡         2
#
#    PIC_WEI PIC_CHU PIC_AREA PIC_SELL_POINT PIC_HX_TOTALPRICE
# 26       2       1      105    三开间朝南，采光面宽阔            305.87
#
# [1 rows x 57 columns]

# %%
room_columes=['room_id','flats','price','totalprice']
df3=pd.read_csv('newHouseRoom.txt',header=None,names=room_columes,dtype={'room_id':object})
# Out:
# /Users/michael/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df3[:10]
# Out:
#   room_id  flats price  totalprice
# 0  129685      1   NaN         NaN
# 1  129683      1   NaN         NaN
# 2  129681      1   NaN         NaN
# 3  129679      1   NaN         NaN
# 4  129677      1   NaN         NaN
# 5  129675      1   NaN         NaN
# 6  129673      1   NaN         NaN
# 7  129671      1   NaN         NaN
# 8  129669      1   NaN         NaN
# 9  129667      1   NaN         NaN

# %%
df_final=df_model.merge(df3,left_on='roomId',right_on='room_id',how='left')

# %%
df_final.dropna(subset=['content'])
# Out:
#            id    app app_version  platform  os_version model_type  \
# 18  696815694  365淘房      8.0.10        22        12.1  Simulator
# 23  696815709  365淘房      8.0.10        22        12.1  Simulator
# 24  696815715  365淘房      8.0.10        22        12.1  Simulator
# 25  696815745  365淘房      8.0.10        22        12.1  Simulator
# 26  696815780  365淘房      8.0.10        22        12.1  Simulator
#
#                                device_id    channel  \
# 18  443048C5-1ECA-4285-9257-33C45C131FC0  App Store
# 23  443048C5-1ECA-4285-9257-33C45C131FC0  App Store
# 24  443048C5-1ECA-4285-9257-33C45C131FC0  App Store
# 25  443048C5-1ECA-4285-9257-33C45C131FC0  App Store
# 26  443048C5-1ECA-4285-9257-33C45C131FC0  App Store
#
#                         user_ip                            session_id  \
# 18  218.94.115.131, 172.17.1.60  1D006168-C7B3-4371-861F-5C334599F7B5
# 23  218.94.115.131, 172.17.1.60  1D006168-C7B3-4371-861F-5C334599F7B5
# 24  218.94.115.131, 172.17.1.60  1D006168-C7B3-4371-861F-5C334599F7B5
# 25  218.94.115.131, 172.17.1.60  1D006168-C7B3-4371-861F-5C334599F7B5
# 26  218.94.115.131, 172.17.1.60  1D006168-C7B3-4371-861F-5C334599F7B5
#
#       ...     PIC_TING PIC_WEI PIC_CHU  PIC_AREA  PIC_SELL_POINT  \
# 18    ...          NaN     NaN     NaN       NaN             NaN
# 23    ...          NaN     NaN     NaN       NaN             NaN
# 24    ...          NaN     NaN     NaN       NaN             NaN
# 25    ...          NaN     NaN     NaN       NaN             NaN
# 26    ...            2       2       1       105     三开间朝南，采光面宽阔
#
#    PIC_HX_TOTALPRICE  room_id flats  price totalprice
# 18               NaN      NaN   NaN    NaN        NaN
# 23               NaN  6688502   4.0  26747     283.33
# 24               NaN      NaN   NaN    NaN        NaN
# 25               NaN      NaN   NaN    NaN        NaN
# 26            305.87      NaN   NaN    NaN        NaN
#
# [5 rows x 61 columns]

# %%
df_final['shaiXuan']
# Out:
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
# 5                    NaN
# 6                    NaN
# 7                    NaN
# 8                    NaN
# 9                    NaN
# 10                   NaN
# 11                   NaN
# 12                   NaN
# 13                   NaN
# 14                   NaN
# 15                   NaN
# 16                   NaN
# 17                   NaN
# 18                   NaN
# 19                   NaN
# 20                   NaN
# 21                   NaN
# 22                   NaN
# 23                   NaN
# 24    筛选_类型_住宅_开盘时间_下月开盘
# 25                   NaN
# 26                   NaN
# Name: shaiXuan, dtype: object

# %%
colName = ["DEVICE_ID", "CONTEXT_ID", "CITY", "DATA_DATE", "LOGIN_ACCOUNT", "START_TIME", "END_TIME", "CONTENT",
                   "OBJECT_ID", "CONTEXT", "OBJECT_ID"]
df = pd.read_csv('newHouseLog.txt', names=colName, header=None,
                         dtype={'LOGIN_ACCOUNT': np.str, 'DATA_DATE': np.str}, delimiter=',')
df
# Out:
# /Users/michael/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/pandas/io/parsers.py:678: UserWarning: Duplicate names specified. This will raise an error in the future.
#   return _read(filepath_or_buffer, kwds)
# /Users/michael/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (9,10) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                                    DEVICE_ID CONTEXT_ID CITY DATA_DATE  \
# 0       263FC589-1874-43CD-8AB4-1997B068E79F        NaN   南京  20190107
# 1                   "shaiXuan" : "位置_区域_浦口区"        NaN  NaN       NaN
# 2                                          }  xflb-sxan  NaN       NaN
# 3                            860477043364719    1-54747   南京  20190107
# 4                            865736032556980   1-226517   南京  20190107
# 5                            868146038592772   1-249547   南京  20190107
# 6                            354732085996916    1-51647   南京  20190107
# 7                            864230038200729   1-246861   南京  20190107
# 8       7EAE093E-DDCE-49BA-A133-DD9641FA7C61   1-229433   南京  20190107
# 9       0F71AAC6-E1FE-4D3A-B9DE-B9A1D0F2634F   1-187573   南京  20190107
# 10                           869874031535451   1-234515   南京  20190107
# 11      7EAE093E-DDCE-49BA-A133-DD9641FA7C61   1-229433   南京  20190107
# 12      40B538AD-D125-41AB-8A0B-809A0308C3A9     1-1429   南京  20190107
# 13      06D5CD45-4852-4C5C-9CD1-B0EF56778086      1-148   芜湖  20190107
# 14      A6A6D1B6-48E8-4F0F-9C26-FE3ED5FDA192     5-1540   南京  20190107
# 15                           869810032010995      1-260   无锡  20190107
# 16                           865297039452533   1-246289   合肥  20190107
# 17      7244FCC4-B8AC-4042-B8F5-C1EC057AAA59    4-54825   南京  20190107
# 18                           354732085996916    1-51647   南京  20190107
# 19                           354732085996916    1-51647   南京  20190107
# 20                           869810032010995      1-260   无锡  20190107
# 21                           865305037064034   1-209867   南京  20190107
# 22      A6A6D1B6-48E8-4F0F-9C26-FE3ED5FDA192     5-1540   南京  20190107
# 23      003D2A4C-0272-4BFE-BFFB-CCC3EC4B8FF5   1-249569   南京  20190107
# 24      40B538AD-D125-41AB-8A0B-809A0308C3A9   1-169969   南京  20190107
# 25                           354732085996916    1-51647   南京  20190107
# 26                           867475039575499   1-236693   徐州  20190107
# 7                                  NaN        NewHouse-Detail-01     NaN
# 8                                  NaN        NewHouse-Detail-01     NaN
# 9                 4室2厅2卫 130㎡ 187573 1               xfxqy-hxlbx     NaN
# 10                                 NaN                       NaN     NaN
# 11                                 NaN  NewHouse-Detail-photo-02     NaN
# 12                                 NaN                       NaN     NaN
# 13                                 NaN                       NaN     NaN
# 14                                 NaN                       NaN     NaN
# 15                                 NaN                       NaN     NaN
# 16                                 NaN                       NaN     NaN
# 17                                 NaN                       NaN     NaN
# 18                                 NaN        NewHouse-Detail-01     NaN
# 19                                 NaN                       NaN     NaN
# 20                                 NaN        NewHouse-Detail-12     NaN
# 21                                 NaN                       NaN     NaN
# 22                   2室2厅1卫 52㎡ 1540 5               xfxqy-hxlbx     NaN
# 23                                 NaN        NewHouse-Detail-01     NaN
# 24                                 NaN                       NaN     NaN
# 25                                 NaN                xfxqy-qbhx     NaN
# 26                                 NaN                       NaN     NaN
# 27                                 NaN  NewHouse-Detail-photo-02     NaN
# 28                                 NaN                       NaN     NaN
# 29                                 NaN                       NaN     NaN
# ...                                ...                       ...     ...
# 116085                             NaN                       NaN     NaN
# 116086                             NaN                       NaN     NaN
# 116087                             NaN                hxlby-hxsx     NaN
# 116088                             NaN                       NaN     NaN
# 116089                             NaN        NewHouse-Detail-08     NaN
# 116090                             NaN                       NaN     NaN
# 116091                             NaN        NewHouse-Detail-12     NaN
# 116092                             NaN                       NaN     NaN
# 116093                             NaN                       NaN     NaN
# 116094  {"shaiXuan":"价格_5000-6000元/㎡"}                 xflb-sxan     NaN
# 116095             2室2厅1卫 87㎡ 234877 1               hxlby-hxlbx     NaN
# 116096                             NaN                       NaN     NaN
# 116097                             NaN                       NaN     NaN
# 116098                2室2厅2卫 97㎡ 577 1               xfxqy-hxlbx     NaN
# 116099                             NaN                       NaN     NaN
# 116100                             NaN                       NaN     NaN
# 116101                             NaN                       NaN     NaN
# 116102        {"shaiXuan":"位置_区域_鸠江区"}                 xflb-sxan     NaN
# 116103                             NaN                       NaN     NaN
# 116104                             NaN                       NaN     NaN
# 116105                             NaN                       NaN     NaN
# 116106                             NaN                       NaN     NaN
# 116107                             NaN                       NaN     NaN
# 116108    {"shaiXuan":"位置_地铁_三号线_广泰门"}                 xflb-sxan     NaN
# 116109                             NaN                       NaN     NaN
# 116110                             NaN                       NaN     NaN
# 116111                             NaN                       NaN     NaN
# 116112                             NaN                       NaN     NaN
# 116113                             NaN                 xfxq-fdxx     NaN
# 116114                             NaN              xfxq-lpdglbx     NaN
#
#        OBJECT_ID.1
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# 5              NaN
# 6              NaN
# 7              NaN
# 8              NaN
# 9              NaN
# 10             NaN
# 11             NaN
# 12             NaN
# 13             NaN
# 14             NaN
# 15             NaN
# 16             NaN
# 17             NaN
# 18             NaN
# 19             NaN
# 20             NaN
# 21             NaN
# 22             NaN
# 23             NaN
# 24             NaN
# 25             NaN
# 26             NaN
# 27             NaN
# 28             NaN
# 29             NaN
# ...            ...
# 116085         NaN
# 116086         NaN
# 116087         NaN
# 116088         NaN
# 116089         NaN
# 116090         NaN
# 116091         NaN
# 116092         NaN
# 116093         NaN
# 116094         NaN
# 116095         NaN
# 116096         NaN
# 116097         NaN
# 116098         NaN
# 116099         NaN
# 116100         NaN
# 116101         NaN
# 116102         NaN
# 116103         NaN
# 116104         NaN
# 116105         NaN
# 116106         NaN
# 116107         NaN
# 116108         NaN
# 116109         NaN
# 116110         NaN
# 116111         NaN
# 116112         NaN
# 116113         NaN
# 116114         NaN
#
# [116115 rows x 11 columns]
