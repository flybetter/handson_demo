# 61230   18118849310  2019-01-18 04:23:24.024  2019-01-18 04:23:26.026
# 61235   18118849310  2019-01-18 04:23:26.026  2019-01-18 04:23:27.027
# 61238   18118849310  2019-01-18 04:23:27.027  2019-01-18 04:23:28.028
# 61239   18118849310                      NaN                      NaN
# 61242   18118849310  2019-01-18 04:23:28.028  2019-01-18 04:23:30.030
# 61248   18118849310  2019-01-18 04:23:30.030  2019-01-18 04:23:31.031
# 61254   18118849310  2019-01-18 04:23:34.034  2019-01-18 04:23:39.039
# 61260   18118849310  2019-01-18 04:23:39.039  2019-01-18 04:23:42.042
# 61266   18118849310                      NaN                      NaN
# 61267   18118849310  2019-01-18 04:23:42.042  2019-01-18 04:23:45.045
# 61274   18118849310  2019-01-18 04:23:45.045  2019-01-18 04:23:48.048
# 61280   18118849310  2019-01-18 04:23:48.048  2019-01-18 04:23:49.049
#
#                                                  CONTENT    OBJECT_ID
# 61070  {\n  "projectType" : "1",\n  "projectId" : "24...          NaN
# 61078  {\n  "modelId" : "2799236",\n  "projectType" :...          NaN
# 61079  {\n  "modelId" : "2799232",\n  "projectType" :...          NaN
# 61080                               4室2厅2卫 143㎡ 240781 1  hxxqy-hxlbx
# 61083                                                NaN   hxxqy-hxtp
# 61090  {\n  "modelId" : "2799232",\n  "projectType" :...          NaN
# 61095  {\n  "modelId" : "2799236",\n  "projectType" :...          NaN
# 61097  {\n  "projectType" : "1",\n  "projectId" : "24...          NaN
# 61162  {\n  "projectType" : "1",\n  "projectId" : "23...          NaN
# 61169  {\n  "modelId" : "2580869",\n  "projectType" :...          NaN
# 61173                                                NaN  hxxqy-fylbx
# 61174  {\n  "roomId" : "6460751",\n  "projectType" : ...          NaN
# 61178  {\n  "modelId" : "2580869",\n  "projectType" :...          NaN
# 61184                                                NaN  hxxqy-fylbx
# 61185  {\n  "roomId" : "6460747",\n  "projectType" : ...          NaN
# 61193  {\n  "modelId" : "2580869",\n  "projectType" :...          NaN
# 61196                                                NaN  hxxqy-fylbx
# 61197  {\n  "roomId" : "6460749",\n  "projectType" : ...          NaN
# 61199  {\n  "modelId" : "2580869",\n  "projectType" :...          NaN
# 61203  {\n  "projectType" : "1",\n  "projectId" : "23...          NaN
# 61208                               3室2厅2卫 117㎡ 234015 1  xfxqy-hxlbx
# 61209  {\n  "modelId" : "2699831",\n  "projectType" :...          NaN
# 61216                                                NaN  hxxqy-fylbx
# 61218  {\n  "roomId" : "5992961",\n  "projectType" : ...          NaN
# 61225  {\n  "modelId" : "2699831",\n  "projectType" :...          NaN
# 61229                                                NaN  hxxqy-fylbx
# 61230  {\n  "roomId" : "5992963",\n  "projectType" : ...          NaN
# 61235  {\n  "modelId" : "2699831",\n  "projectType" :...          NaN
# 61238  {\n  "roomId" : "5992965",\n  "projectType" : ...          NaN
# 61239                                                NaN  hxxqy-fylbx
# 61242  {\n  "modelId" : "2699831",\n  "projectType" :...          NaN
# 61248  {\n  "projectType" : "1",\n  "projectId" : "23...          NaN
# 61254  {\n  "projectType" : "1",\n  "projectId" : "23...          NaN
# 61260  {\n  "modelId" : "2564477",\n  "projectType" :...          NaN
# 61266                                                NaN  hxxqy-fylbx
# 61267  {\n  "roomId" : "4590511",\n  "projectType" : ...          NaN
# 61274  {\n  "modelId" : "2564477",\n  "projectType" :...          NaN
# 61280  {\n  "projectType" : "1",\n  "projectId" : "23...          NaN

# %%
# from pandas.io.json import json_normalize

# %%
# df['content']

# %%
# import json
# def custom(x):
#     try:
#         object=json.loads(x)
#         return (object['roomId'],object['projectType'],object['projectId'])
#     except:
#         return (np.NAN,np.NAN,np.NAN)
    
# (df['roomId'],df['projectType'],df['projectId'])=df['content'].apply(custom)

# %%
import json
# def custom(df):
#     try:
#         object=json.loads(df['content'])
#         df['roomId']=object.get('roomId',np.NaN)
#         df['projectType']=object.get('projectType',np.NaN)
#         df['modelId']=object.get('modelId',np.NaN)
#         df['projectId']=object.get('projectId',np.ALLOW_THREADSNaN)
#         df['shaiXuan']=object.get('shaiXuan',np.NaN)
#         return df
#     except:
#         df['roomId']=np.NaN
#         df['projectType']=np.NaN
#         df['modelId']=np.NaN
#         df['projectId']=np.NaN
#         df['shaiXuan']=np.NaN
#         return df

def custom(df):
    try:
        object = json.loads(df['CONTENT'])
        df['ROOMID'] = object.get('roomId', np.NaN)
        df['PROJECTTYPE'] = object.get('projectType', np.NaN)
        df['MODELID'] = object.get('modelId', np.NaN)
        df['PROJECTID'] = object.get('projectId', np.NaN)
        df['SHAIXUAN'] = object.get('shaiXuan', np.NaN)
        return df
    except:
        df['ROOMID'] = np.NaN
        df['PROJECTTYPE'] = np.NaN
        df['MODELID'] = np.NaN
        df['PROJECTID'] = np.NaN
        df['SHAIXUAN'] = np.NaN
        return df
    
df=df.apply(custom,axis=1)

# %%
df.dropna(subset=['CONTENT'])
# Out:
#                                   DEVICE_ID CONTEXT_ID CITY  DATA_DATE  \
# 61070  A5B9DA9F-40C6-4DE4-9539-3A288CE6B614   1-240781   南京   20190118
# 61078  A5B9DA9F-40C6-4DE4-9539-3A288CE6B614   1-240781   南京   20190118
# 61079  A5B9DA9F-40C6-4DE4-9539-3A288CE6B614   1-240781   南京   20190118
# 61080  A5B9DA9F-40C6-4DE4-9539-3A288CE6B614   1-240781   南京   20190118
# 61090  A5B9DA9F-40C6-4DE4-9539-3A288CE6B614   1-240781   南京   20190118
# 61095  A5B9DA9F-40C6-4DE4-9539-3A288CE6B614   1-240781   南京   20190118
# 61097  A5B9DA9F-40C6-4DE4-9539-3A288CE6B614   1-240781   南京   20190118
# 61162  A5B9DA9F-40C6-4DE4-9539-3A288CE6B614   1-234015   南京   20190118
# 61169  A5B9DA9F-40C6-4DE4-9539-3A288CE6B614   1-234015   南京   20190118
# 61174  A5B9DA9F-40C6-4DE4-9539-3A288CE6B614   1-234015   南京   20190118
# 61178  A5B9DA9F-40C6-4DE4-9539-3A288CE6B614   1-234015   南京   20190118
# 61185  A5B9DA9F-40C6-4DE4-9539-3A288CE6B614   1-234015   南京   20190118
# 61193  A5B9DA9F-40C6-4DE4-9539-3A288CE6B614   1-234015   南京   20190118
# 61197  A5B9DA9F-40C6-4DE4-9539-3A288CE6B614   1-234015   南京   20190118
# 61199  A5B9DA9F-40C6-4DE4-9539-3A288CE6B614   1-234015   南京   20190118
# 61203  A5B9DA9F-40C6-4DE4-9539-3A288CE6B614   1-234015   南京   20190118
# 61208  A5B9DA9F-40C6-4DE4-9539-3A288CE6B614   1-234015   南京   20190118
# 61209  A5B9DA9F-40C6-4DE4-9539-3A288CE6B614   1-234015   南京   20190118
# 61218  A5B9DA9F-40C6-4DE4-9539-3A288CE6B614   1-234015   南京   20190118
# 61225  A5B9DA9F-40C6-4DE4-9539-3A288CE6B614   1-234015   南京   20190118
# 61230  A5B9DA9F-40C6-4DE4-9539-3A288CE6B614   1-234015   南京   20190118
# 61235  A5B9DA9F-40C6-4DE4-9539-3A288CE6B614   1-234015   南京   20190118
# 61238  A5B9DA9F-40C6-4DE4-9539-3A288CE6B614   1-234015   南京   20190118
# 61242  A5B9DA9F-40C6-4DE4-9539-3A288CE6B614   1-234015   南京   20190118
# 61248  A5B9DA9F-40C6-4DE4-9539-3A288CE6B614   1-234015   南京   20190118
# 61254  A5B9DA9F-40C6-4DE4-9539-3A288CE6B614   1-238817   南京   20190118
# 61260  A5B9DA9F-40C6-4DE4-9539-3A288CE6B614   1-238817   南京   20190118
# 61267  A5B9DA9F-40C6-4DE4-9539-3A288CE6B614   1-238817   南京   20190118
# 61274  A5B9DA9F-40C6-4DE4-9539-3A288CE6B614   1-238817   南京   20190118
# 61280  A5B9DA9F-40C6-4DE4-9539-3A288CE6B614   1-238817   南京   20190118
#
#       LOGIN_ACCOUNT               START_TIME                 END_TIME  \
# 61070   18118849310  2019-01-18 04:21:59.059  2019-01-18 04:22:03.003
# 61078   18118849310  2019-01-18 04:22:03.003  2019-01-18 04:22:05.005
# 61079   18118849310  2019-01-18 04:22:05.005  2019-01-18 04:22:07.007
# 61080   18118849310                      NaN                      NaN
# 61090   18118849310  2019-01-18 04:22:07.007  2019-01-18 04:22:08.008
# 61197  {\n  "roomId" : "6460749",\n  "projectType" : ...          NaN
# 61199  {\n  "modelId" : "2580869",\n  "projectType" :...          NaN
# 61203  {\n  "projectType" : "1",\n  "projectId" : "23...          NaN
# 61208                               3室2厅2卫 117㎡ 234015 1  xfxqy-hxlbx
# 61209  {\n  "modelId" : "2699831",\n  "projectType" :...          NaN
# 61218  {\n  "roomId" : "5992961",\n  "projectType" : ...          NaN
# 61225  {\n  "modelId" : "2699831",\n  "projectType" :...          NaN
# 61230  {\n  "roomId" : "5992963",\n  "projectType" : ...          NaN
# 61235  {\n  "modelId" : "2699831",\n  "projectType" :...          NaN
# 61238  {\n  "roomId" : "5992965",\n  "projectType" : ...          NaN
# 61242  {\n  "modelId" : "2699831",\n  "projectType" :...          NaN
# 61248  {\n  "projectType" : "1",\n  "projectId" : "23...          NaN
# 61254  {\n  "projectType" : "1",\n  "projectId" : "23...          NaN
# 61260  {\n  "modelId" : "2564477",\n  "projectType" :...          NaN
# 61267  {\n  "roomId" : "4590511",\n  "projectType" : ...          NaN
# 61274  {\n  "modelId" : "2564477",\n  "projectType" :...          NaN
# 61280  {\n  "projectType" : "1",\n  "projectId" : "23...          NaN
#
#         ROOMID PROJECTTYPE  MODELID PROJECTID  SHAIXUAN
# 61070      NaN           1      NaN    240781       NaN
# 61078      NaN           1  2799236    240781       NaN
# 61079      NaN           1  2799232    240781       NaN
# 61080      NaN         NaN      NaN       NaN       NaN
# 61090      NaN           1  2799232    240781       NaN
# 61095      NaN           1  2799236    240781       NaN
# 61097      NaN           1      NaN    240781       NaN
# 61162      NaN           1      NaN    234015       NaN
# 61169      NaN           1  2580869    234015       NaN
# 61174  6460751           1      NaN    234015       NaN
# 61178      NaN           1  2580869    234015       NaN
# 61185  6460747           1      NaN    234015       NaN
# 61193      NaN           1  2580869    234015       NaN
# 61197  6460749           1      NaN    234015       NaN
# 61199      NaN           1  2580869    234015       NaN
# 61203      NaN           1      NaN    234015       NaN
# 61208      NaN         NaN      NaN       NaN       NaN
# 61209      NaN           1  2699831    234015       NaN
# 61218  5992961           1      NaN    234015       NaN
# 61225      NaN           1  2699831    234015       NaN
# 61230  5992963           1      NaN    234015       NaN
# 61235      NaN           1  2699831    234015       NaN
# 61238  5992965           1      NaN    234015       NaN
# 61242      NaN           1  2699831    234015       NaN
# 61248      NaN           1      NaN    234015       NaN
# 61254      NaN           1      NaN    238817       NaN
# 61260      NaN           1  2564477    238817       NaN
# 61267  4590511           1      NaN    238817       NaN
# 61274      NaN           1  2564477    238817       NaN
# 61280      NaN           1      NaN    238817       NaN

# %%
columns=[ 'PIC_ID','PIC_PRJID','PIC_PRJNAME','PIC_TYPE','PIC_DESC','PIC_TING','PIC_WEI','PIC_CHU','PIC_AREA','PIC_SELL_POINT','PIC_HX_TOTALPRICE' ]
df2=pd.read_csv('newHouseModel.txt', names=columns,header=None ,dtype={'PIC_ID':object})
# Out:
# /Users/michael/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (3,6,7,8,10) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df2[:10]
# Out:
#   PIC_ID  PIC_PRJID PIC_PRJNAME PIC_TYPE        PIC_DESC PIC_TING PIC_WEI  \
# 0      1          1      东恒阳光嘉园        3       a1 拷贝.jpg        0       0
# 1      2          1      东恒阳光嘉园        3       a2 拷贝.jpg        0       0
# 2      3          1      东恒阳光嘉园        3       a3 拷贝.jpg        0       0
# 3      4          1      东恒阳光嘉园        3       b1 拷贝.jpg        0       0
# 4      5          1      东恒阳光嘉园        3       b2 拷贝.jpg        0       0
# 5      6          1      东恒阳光嘉园        3       b3 拷贝.jpg        0       0
# 6      7          1      东恒阳光嘉园        3  C09-二层平面_w.jpg        0       0
# 7      8          1      东恒阳光嘉园        3       c1 拷贝.jpg        0       0
# 8      9          1      东恒阳光嘉园        3       c2 拷贝.jpg        0       0
# 9     10          1      东恒阳光嘉园        3       c3 拷贝.jpg        0       0
#
#   PIC_CHU PIC_AREA PIC_SELL_POINT PIC_HX_TOTALPRICE
# 0       0        0            NaN               NaN
# 1       0        0            NaN               NaN
# 2       0        0            NaN               NaN
# 3       0        0            NaN               NaN
# 4       0        0            NaN               NaN
# 5       0        0            NaN               NaN
# 6       0        0            NaN               NaN
# 7       0        0            NaN               NaN
# 8       0        0            NaN               NaN
# 9       0        0            NaN               NaN

# %%
# df.info()

# %%
# df2.info()

# %%
df_model=df.merge(df2,left_on='MODELID',right_on='PIC_ID',how='left')

# %%
df_model.dropna(subset=['PIC_PRJID'])
# Out:
#                                DEVICE_ID CONTEXT_ID CITY  DATA_DATE  \
# 9   A5B9DA9F-40C6-4DE4-9539-3A288CE6B614   1-234015   南京   20190118
# 12  A5B9DA9F-40C6-4DE4-9539-3A288CE6B614   1-234015   南京   20190118
# 15  A5B9DA9F-40C6-4DE4-9539-3A288CE6B614   1-234015   南京   20190118
# 18  A5B9DA9F-40C6-4DE4-9539-3A288CE6B614   1-234015   南京   20190118
# 21  A5B9DA9F-40C6-4DE4-9539-3A288CE6B614   1-234015   南京   20190118
# 24  A5B9DA9F-40C6-4DE4-9539-3A288CE6B614   1-234015   南京   20190118
# 27  A5B9DA9F-40C6-4DE4-9539-3A288CE6B614   1-234015   南京   20190118
# 30  A5B9DA9F-40C6-4DE4-9539-3A288CE6B614   1-234015   南京   20190118
# 33  A5B9DA9F-40C6-4DE4-9539-3A288CE6B614   1-238817   南京   20190118
# 36  A5B9DA9F-40C6-4DE4-9539-3A288CE6B614   1-238817   南京   20190118
#
#    LOGIN_ACCOUNT               START_TIME                 END_TIME  \
# 9    18118849310  2019-01-18 04:23:00.000  2019-01-18 04:23:03.003
# 12   18118849310  2019-01-18 04:23:05.005  2019-01-18 04:23:08.008
# 15   18118849310  2019-01-18 04:23:11.011  2019-01-18 04:23:12.012
# 18   18118849310  2019-01-18 04:23:13.013  2019-01-18 04:23:14.014
# 21   18118849310  2019-01-18 04:23:16.016  2019-01-18 04:23:21.021
# 24   18118849310  2019-01-18 04:23:23.023  2019-01-18 04:23:24.024
# 27   18118849310  2019-01-18 04:23:26.026  2019-01-18 04:23:27.027
# 30   18118849310  2019-01-18 04:23:28.028  2019-01-18 04:23:30.030
# 33   18118849310  2019-01-18 04:23:39.039  2019-01-18 04:23:42.042
# 36   18118849310  2019-01-18 04:23:45.045  2019-01-18 04:23:48.048
#
#                                               CONTENT OBJECT_ID ROOMID  \
# 9   {\n  "modelId" : "2580869",\n  "projectType" :...       NaN    NaN
# 12  {\n  "modelId" : "2580869",\n  "projectType" :...       NaN    NaN
# 15  {\n  "modelId" : "2580869",\n  "projectType" :...       NaN    NaN
# 18  {\n  "modelId" : "2580869",\n  "projectType" :...       NaN    NaN
# 21  {\n  "modelId" : "2699831",\n  "projectType" :...       NaN    NaN
# 24  {\n  "modelId" : "2699831",\n  "projectType" :...       NaN    NaN
# 27  {\n  "modelId" : "2699831",\n  "projectType" :...       NaN    NaN
# 30  {\n  "modelId" : "2699831",\n  "projectType" :...       NaN    NaN
# 33  {\n  "modelId" : "2564477",\n  "projectType" :...       NaN    NaN
# 36  {\n  "modelId" : "2564477",\n  "projectType" :...       NaN    NaN
#
#           ...        PIC_PRJID PIC_PRJNAME PIC_TYPE      PIC_DESC PIC_TING  \
# 9         ...         234015.0          熙悦       10    熙悦E户型图128㎡        2
# 12        ...         234015.0          熙悦       10    熙悦E户型图128㎡        2
# 15        ...         234015.0          熙悦       10    熙悦E户型图128㎡        2
# 18        ...         234015.0          熙悦       10    熙悦E户型图128㎡        2
# 21        ...         234015.0          熙悦       10    熙悦D2户型117㎡        2
# 24        ...         234015.0          熙悦       10    熙悦D2户型117㎡        2
# 27        ...         234015.0          熙悦       10    熙悦D2户型117㎡        2
# 30        ...         234015.0          熙悦       10    熙悦D2户型117㎡        2
# 33        ...         238817.0      万科金域国际        9  万科金域国际90㎡户型图        2
# 36        ...         238817.0      万科金域国际        9  万科金域国际90㎡户型图        2
#
#     PIC_WEI PIC_CHU PIC_AREA PIC_SELL_POINT PIC_HX_TOTALPRICE
# 9         2       1      128    三开间并排朝南，采光好            374.68
# 12        2       1      128    三开间并排朝南，采光好            374.68
# 15        2       1      128    三开间并排朝南，采光好            374.68
# 18        2       1      128    三开间并排朝南，采光好            374.68
# 21        2       1      117     户型方正、三开间朝南               338
# 24        2       1      117     户型方正、三开间朝南               338
# 27        2       1      117     户型方正、三开间朝南               338
# 30        2       1      117     户型方正、三开间朝南               338
# 33        1       1       90      户型方正 南北通透            254.68
# 36        1       1       90      户型方正 南北通透            254.68
#
# [10 rows x 25 columns]

# %%
room_columes=['room_id','flats','price','totalprice']
df3=pd.read_csv('newHouseRoom.txt',header=None, names=room_columes, dtype={'room_id':object} ,low_memory=False)

# %%
df3[:10]
# Out:
#   room_id  flats price  totalprice
# 0  129685      1   NaN         NaN
# 1  129683      1   NaN         NaN
# 2  129681      1   NaN         NaN
# 3  129679      1   NaN         NaN
# 4  129677      1   NaN         NaN
# 5  129675      1   NaN         NaN
# 6  129673      1   NaN         NaN
# 7  129671      1   NaN         NaN
# 8  129669      1   NaN         NaN
# 9  129667      1   NaN         NaN

# %%
df_final=df_model.merge(df3,left_on='ROOMID',right_on='room_id',how='left')

# %%
df_final.dropna(subset=['CONTENT'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-19-1d33ca56de7f> in <module>()
# ----> 1 df_final.dropna(subset=['content'])
#
# ~/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/pandas/core/frame.py in dropna(self, axis, how, thresh, subset, inplace)
#    4280                 check = indices == -1
#    4281                 if check.any():
# -> 4282                     raise KeyError(list(np.compress(check, subset)))
#    4283                 agg_obj = self.take(indices, axis=agg_axis)
#    4284
#
# KeyError: ['content']
