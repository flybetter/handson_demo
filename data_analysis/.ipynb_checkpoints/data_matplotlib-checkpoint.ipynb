# %%
import matplotlib.pyplot as plt

# %%
fig=plt.figure()

# %%
ax1=fig.add_subplot(2,2,1)
ax2=fig.add_subplot(2,2,2)
ax3=fig.add_subplot(2,2,3)

# %%
from numpy.random import randn
import numpy as np
ax3.plot(randn(50).cumsum(),'k--')
plt.show()

# %%
ax1.hist(randn(100),bins=20,color='k',alpha=0.3)
# Out:
# (array([ 1.,  0.,  0.,  3.,  4.,  6.,  7.,  7., 11.,  5., 12.,  9.,  9.,
#          7., 10.,  3.,  3.,  2.,  0.,  1.]),
#  array([-2.59334194, -2.33299997, -2.072658  , -1.81231603, -1.55197406,
#         -1.29163209, -1.03129012, -0.77094815, -0.51060618, -0.25026421,
#          0.01007776,  0.27041973,  0.5307617 ,  0.79110367,  1.05144564,
#          1.31178761,  1.57212958,  1.83247155,  2.09281352,  2.35315549,
#          2.61349746]),
#  <a list of 20 Patch objects>)

# %%
ax2.scatter(np.arange(30),np.arange(30)+3*randn(30))

# %%
fig=plt.figure()
ax=fig.add_subplot(349)
ax.plot(np.random.randn(50).cumsum(),'k--')

# %%
plt.show()

# %%
plt.scatter(np.arange(30),np.arange(30)+3*randn(30))

# %%
fig=plt.figure()
ax1=fig.add_subplot(221)
ax2=fig.add_subplot(222)
ax3=fig.add_subplot(223)
ax3.plot(randn(50).cumsum(),'k--')
_=ax1.hist(randn(100),bins=20,color='k',alpha=0.3)
ax2.scatter(np.arange(30),np.arange(30)+3*randn(30))

# %%
fig,axes=plt.subplots(2,2,sharex=True,sharey=True)
for i in range(2):
    for j in range(2):
        axes[i,j].hist(randn(500),bins=50,color='k',alpha=0.5)
plt.subplots_adjust(wspace=0,hspace=0)

# %%
plt.plot(randn(30).cumsum(),'ko--')

# %%
import pandas as pd

# %%
s=pd.Series(np.random.randn(10).cumsum(),index=np.arange(0,100,10))
s.plot()

# %%
df=pd.DataFrame(np.random.randn(10,4).cumsum(0),
               columns=['A','B','C','D'],
               index=np.arange(0,100,10))
df.plot()

# %%
fig,axes=plt.subplots(2,1)
data=pd.Series(np.random.rand(16),index=list('abcdefghijklmnop'))
data.plot(kind='bar',ax=axes[0],color='k',alpha=0.7)
data.plot(kind='barh',ax=axes[1],color='k',alpha=0.7)

# %%
df=pd.DataFrame(np.random.rand(6,4),index=['one','two','three','four','five','six'],
               columns=pd.Index(['A','B','C','D'],name='Genus'))
df
# Out:
# Genus         A         B         C         D
# one    0.086602  0.650301  0.035550  0.942602
# two    0.498369  0.350867  0.466338  0.301935
# three  0.293133  0.694628  0.551924  0.401794
# four   0.210557  0.520543  0.029744  0.861423
# five   0.353966  0.013502  0.492354  0.605051
# six    0.027174  0.379541  0.916778  0.898683

# %%
df.plot(kind='bar')

# %%
df.plot(kind='barh',stacked=True)

# %%
comp1=np.random.normal(0,1,size=200)
comp2=np.random.normal(10,2,size=200)
values=pd.Series(np.concatenate([comp1,comp2]))
values.hist(bins=100,alpha=0.3,color='k',normed=True)
values.plot(kind='kde',style='k--')
# Out:
# /Users/michael/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
df =pd.DataFrame({'key1':['a','a','b','b','a'],
                 'key2':['one','two','one','two','one'],
                 'data1':np.random.randn(5),
                 'data2':np.random.randn(5)})
df
# Out:
#   key1 key2     data1     data2
# 0    a  one  0.160104 -1.135408
# 1    a  two  0.155488 -3.161880
# 2    b  one  3.169029  0.078093
# 3    b  two -0.963065  0.478496
# 4    a  one -1.047043  0.626551

# %%
grouped=df['data1'].groupby(df['key1'])

# %%
grouped

# %%
grouped.mean()
# Out:
# key1
# a   -0.243817
# b    1.102982
# Name: data1, dtype: float64

# %%
grouped.quantile()
# Out:
# key1
# a    0.155488
# b    1.102982
# Name: data1, dtype: float64

# %%
means=df['data1'].groupby([df['key1'],df['key2']]).mean()

# %%
means
# Out:
# key1  key2
# a     one    -0.443470
#       two     0.155488
# b     one     3.169029
#       two    -0.963065
# Name: data1, dtype: float64

# %%
means.unstack()
# Out:
# key2       one       two
# key1
# a    -0.443470  0.155488
# b     3.169029 -0.963065

# %%
states=np.array(['Ohio','California','California','Ohio','Ohio'])

# %%
years=np.array([2005,2005,2006,2005,2006])

# %%
df['data1'].groupby([states,years]).mean()
# Out:
# California  2005    0.155488
#             2006    3.169029
# Ohio        2005   -0.401481
#             2006   -1.047043
# Name: data1, dtype: float64

# %%
df.groupby('key1').mean()
# Out:
#          data1     data2
# key1
# a    -0.243817 -1.223579
# b     1.102982  0.278294

# %%
df.groupby(['key1','key2']).mean()
# Out:
#               data1     data2
# key1 key2
# a    one  -0.443470 -0.254429
#      two   0.155488 -3.161880
# b    one   3.169029  0.078093
#      two  -0.963065  0.478496

# %%
df.groupby(['key1','key2']).size()
# Out:
# key1  key2
# a     one     2
#       two     1
# b     one     1
#       two     1
# dtype: int64

# %%
for name,group in df.groupby('key1'):
    print(name)
    print(group)
# Out:
# a
#   key1 key2     data1     data2
# 0    a  one  0.160104 -1.135408
# 1    a  two  0.155488 -3.161880
# 4    a  one -1.047043  0.626551
# b
#   key1 key2     data1     data2
# 2    b  one  3.169029  0.078093
# 3    b  two -0.963065  0.478496

# %%
for (k1,k2),group in df.groupby(['key1','key2']):
    print((k1,k2))
    print(group)
# Out:
# ('a', 'one')
#   key1 key2     data1     data2
# 0    a  one  0.160104 -1.135408
# 4    a  one -1.047043  0.626551
# ('a', 'two')
#   key1 key2     data1    data2
# 1    a  two  0.155488 -3.16188
# ('b', 'one')
#   key1 key2     data1     data2
# 2    b  one  3.169029  0.078093
# ('b', 'two')
#   key1 key2     data1     data2
# 3    b  two -0.963065  0.478496

# %%
pieces= dict(list(df.groupby('key1')))

# %%
pieces['b']
# Out:
#   key1 key2     data1     data2
# 2    b  one  3.169029  0.078093
# 3    b  two -0.963065  0.478496

# %%
df.groupby('key1')['data1']

# %%
df['data1'].groupby(df['key1'])

# %%
people=pd.DataFrame(np.random.randn(5,5),
                columns=['a','b','c','d','e'],
                index=['Joe','Steve','Wes','Jim','Travis'])
people.ix[2:3,['b','c']]=np.nan
people
# Out:
# /Users/michael/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/ipykernel_launcher.py:4: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   after removing the cwd from sys.path.
#                a         b         c         d         e
# Joe     0.762694 -0.274108  0.834515  0.512030  1.636278
# Steve   2.146214 -0.934644  2.201543 -0.817552  1.322347
# Wes     0.325140       NaN       NaN  1.555284 -1.254561
# Jim     0.281201  0.138671 -1.654380 -0.499796  0.109170
# Travis -0.424949  0.558973 -0.657878 -1.264469  0.411628

# %%
mapping={'a':'red','b':'red','c':'blue',
        'd':'blue','e':'red','f':'orange'}
by_column=people.groupby(mapping,axis=1)

# %%
by_column.sum()
# Out:
#             blue       red
# Joe     1.346545  2.124864
# Steve   1.383991  2.533917
# Wes     1.555284 -0.929421
# Jim    -2.154176  0.529043
# Travis -1.922347  0.545652

# %%
people
# Out:
#                a         b         c         d         e
# Joe     0.762694 -0.274108  0.834515  0.512030  1.636278
# Steve   2.146214 -0.934644  2.201543 -0.817552  1.322347
# Wes     0.325140       NaN       NaN  1.555284 -1.254561
# Jim     0.281201  0.138671 -1.654380 -0.499796  0.109170
# Travis -0.424949  0.558973 -0.657878 -1.264469  0.411628

# %%
people.groupby(len).mean()
# Out:
#           a         b         c         d         e
# 3  0.456345 -0.067718 -0.409933  0.522506  0.163629
# 5  2.146214 -0.934644  2.201543 -0.817552  1.322347
# 6 -0.424949  0.558973 -0.657878 -1.264469  0.411628

# %%
key_list=['one','one','one','two','two']
people.groupby([len,key_list]).min()
# Out:
#               a         b         c         d         e
# 3 one  0.325140 -0.274108  0.834515  0.512030 -1.254561
#   two  0.281201  0.138671 -1.654380 -0.499796  0.109170
# 5 one  2.146214 -0.934644  2.201543 -0.817552  1.322347
# 6 two -0.424949  0.558973 -0.657878 -1.264469  0.411628

# %%
df
# Out:
#   key1 key2     data1     data2
# 0    a  one  0.160104 -1.135408
# 1    a  two  0.155488 -3.161880
# 2    b  one  3.169029  0.078093
# 3    b  two -0.963065  0.478496
# 4    a  one -1.047043  0.626551

# %%
grouped=df.groupby('key1')

# %%
grouped['data1'].quantile(0.9)
# Out:
# key1
# a    0.15918
# b    2.75582
# Name: data1, dtype: float64

# %%
def peak_to_peak(arr):
    return arr.max()-arr.min()

grouped.agg(peak_to_peak)
# Out:
#          data1     data2
# key1
# a     1.207147  3.788431
# b     4.132094  0.400403

# %%
grouped.describe()
# Out:
#      data1                                                              \
#      count      mean       std       min       25%       50%       75%
# key1
# a      3.0 -0.243817  0.695618 -1.047043 -0.445778  0.155488  0.157796
# b      2.0  1.102982  2.921831 -0.963065  0.069959  1.102982  2.136006
#
#                data2                                                    \
#            max count      mean       std       min       25%       50%
# key1
# a     0.160104   3.0 -1.223579  1.895754 -3.161880 -2.148644 -1.135408
# b     3.169029   2.0  0.278294  0.283128  0.078093  0.178194  0.278294
#
#
#            75%       max
# key1
# a    -0.254429  0.626551
# b     0.378395  0.478496

# %%
df
# Out:
#   key1 key2     data1     data2
# 0    a  one  0.160104 -1.135408
# 1    a  two  0.155488 -3.161880
# 2    b  one  3.169029  0.078093
# 3    b  two -0.963065  0.478496
# 4    a  one -1.047043  0.626551

# %%
k1_means=df.groupby('key1').mean().add_prefix('mean_')

# %%
k1_means
# Out:
#       mean_data1  mean_data2
# key1
# a      -0.243817   -1.223579
# b       1.102982    0.278294

# %%
pd.merge(df,k1_means,left_on='key1',right_index=True)
# Out:
#   key1 key2     data1     data2  mean_data1  mean_data2
# 0    a  one  0.160104 -1.135408   -0.243817   -1.223579
# 1    a  two  0.155488 -3.161880   -0.243817   -1.223579
# 4    a  one -1.047043  0.626551   -0.243817   -1.223579
# 2    b  one  3.169029  0.078093    1.102982    0.278294
# 3    b  two -0.963065  0.478496    1.102982    0.278294

# %%
key=['one','two','one','two','one']
people.groupby(key).mean()
# Out:
#             a         b         c         d         e
# one  0.220962  0.142433  0.088318  0.267615  0.264448
# two  1.213708 -0.397986  0.273581 -0.658674  0.715758

# %%
people.groupby(key).transform(np.mean)
# Out:
#                a         b         c         d         e
# Joe     0.220962  0.142433  0.088318  0.267615  0.264448
# Steve   1.213708 -0.397986  0.273581 -0.658674  0.715758
# Wes     0.220962  0.142433  0.088318  0.267615  0.264448
# Jim     1.213708 -0.397986  0.273581 -0.658674  0.715758
# Travis  0.220962  0.142433  0.088318  0.267615  0.264448

# %%
def demean(arr):
    return arr-arr.mean()

demeaned=people.groupby(key).transform(demean)

demeaned
# Out:
#                a         b         c         d         e
# Joe     0.541732 -0.416541  0.746196  0.244415  1.371830
# Steve   0.932506 -0.536658  1.927962 -0.158878  0.606588
# Wes     0.104179       NaN       NaN  1.287669 -1.519010
# Jim    -0.932506  0.536658 -1.927962  0.158878 -0.606588
# Travis -0.645911  0.416541 -0.746196 -1.532084  0.147180

# %%
frame=pd.DataFrame({'data1':np.random.randn(1000),
                   'data2':np.random.randn(1000)})

frame.head(10)
# Out:
#       data1     data2
# 0 -1.684769 -0.153886
# 1 -1.360123 -0.209626
# 2 -0.417337 -0.428077
# 3 -1.354067  0.538441
# 4  0.709298  1.040040
# 5  0.170312 -1.066584
# 6 -2.389305 -1.242540
# 7 -1.277534 -0.979767
# 8 -1.037736  0.151425
# 9  0.977397 -0.662613

# %%
factor=pd.cut(frame.data1,4)

# %%
factor.describe()
# Out:
# count                 1000
# unique                   4
# top       (-0.0315, 1.477]
# freq                   440
# Name: data1, dtype: object

# %%
def get_stats(group):
    return {'min':group.min(),'max':group.max(),
           'count':group.count(),'mean':group.mean()}

grouped=frame.data2.groupby(factor)

grouped.apply(get_stats).unstack()
# Out:
#                   count       max      mean       min
# data1
# (-3.054, -1.54]    57.0  1.765850  0.090848 -2.840605
# (-1.54, -0.0315]  439.0  3.093381  0.029111 -3.204435
# (-0.0315, 1.477]  440.0  3.372710 -0.035675 -3.393455
# (1.477, 2.985]     64.0  1.585396  0.050327 -1.934207

# %%
grouping=pd.qcut(frame.data1,10,labels=False)

grouped=frame.data2.groupby(grouping)

grouped.apply(get_stats).unstack()
# Out:
#        count       max      mean       min
# data1
# 0      100.0  2.145533 -0.095749 -2.840605
# 1      100.0  2.556435  0.087492 -3.204435
# 2      100.0  2.232505  0.015514 -2.413194
# 3      100.0  2.386430 -0.003421 -2.261875
# 4      100.0  3.093381  0.156716 -1.936524
# 5      100.0  2.516273 -0.127856 -2.805093
# 6      100.0  3.372710 -0.100920 -2.565300
# 7      100.0  2.531285  0.167944 -3.393455
# 8      100.0  1.921341 -0.112576 -2.982575
# 9      100.0  2.517242  0.067674 -2.125601

# %%
s= pd.Series(np.random.randn(6))
s[::2]=np.nan
s
# Out:
# 0         NaN
# 1   -0.675767
# 2         NaN
# 3   -1.591016
# 4         NaN
# 5    1.534229
# dtype: float64

# %%
s.fillna(s.mean())
# Out:
# 0   -0.244185
# 1   -0.675767
# 2   -0.244185
# 3   -1.591016
# 4   -0.244185
# 5    1.534229
# dtype: float64

# %%
# suits=['H','S','C','D']
# card_val=(list(range(1,11))+[10]*3)*4

# base_names=['A']+range(2,11)+['J','K','Q']

# cards=[]

# for suit in ['H','S','C','D']:
#     cards.extend(str(num)+suit for num in base_names)
    
# check=Series(card_val,index=cards)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-92-c37d3071c2a4> in <module>()
#       2 card_val=(list(range(1,11))+[10]*3)*4
#       3
# ----> 4 base_names=['A']+range(2,11)+['J','K','Q']
#       5
#       6 cards=[]
#
# TypeError: can only concatenate list (not "range") to list

# %%
df=pd.DataFrame({'category':['a','a','a','a','b','b','b','b'],
             'data':np.random.randn(8),
             'weights':np.random.randn(8)})

df
# Out:
#   category      data   weights
# 0        a  0.732104  0.223604
# 1        a  0.218430  1.318565
# 2        a  1.348732  0.875584
# 3        a  0.660069  0.616399
# 4        b  0.479599 -0.289522
# 5        b -0.319834 -0.472110
# 6        b  1.637693 -0.929864
# 7        b  0.013586 -1.223419

# %%
grouped=df.groupby('category')

# %%
get_wavg=lambda g:np.average(g['data'],weights=g['weights'])

grouped.apply(get_wavg)
# Out:
# category
# a    0.672184
# b    0.523964
# dtype: float64

# %%
# review all the book
# review andrew video
