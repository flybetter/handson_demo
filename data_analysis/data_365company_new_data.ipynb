# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('demo.csv')
# Out:
# /Users/michael/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (1,14,24,25,33,34) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head(100)
# Out:
#     Unnamed: 0                             DEVICE_ID CONTEXT_ID CITY_x  \
# 0        35624                              00000000   4-249969     芜湖
# 1        35625                              00000000   4-249969     芜湖
# 2        35626                              00000000   4-249969     芜湖
# 3        35627                              00000000   1-241647     芜湖
# 4        43644                              00000000     1-1402     南京
# 5        43646                              00000000     1-1402     南京
# 6        43675                              00000000     1-1402     南京
# 7        43713                              00000000    1-51655     南京
# 8        43714                              00000000    1-51655     南京
# 9        43961                              00000000    1-51655     南京
# 10       43962                              00000000    1-51655     南京
# 11      212908                              00000000    1-54595     南京
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 594536 entries, 0 to 594535
# Data columns (total 43 columns):
# Unnamed: 0           594536 non-null int64
# DEVICE_ID            594536 non-null object
# CONTEXT_ID           594536 non-null object
# CITY_x               594536 non-null object
# DATA_DATE            594536 non-null object
# LOGIN_ACCOUNT        183001 non-null float64
# START_TIME           594536 non-null object
# END_TIME             594536 non-null object
# CONTENT              550896 non-null object
# OBJECT_ID            0 non-null float64
# CHANNEL              594536 non-null float64
# CONTEXT              594536 non-null float64
# ROOMID               9822 non-null float64
# PROJECTTYPE          550896 non-null float64
# MODELID              152505 non-null object
# PROJECTID            550896 non-null float64
# SHAIXUAN             0 non-null float64
# PRJ_LISTID           580202 non-null float64
# CITY_y               580202 non-null object
# ...

# %%
df.groupby('DATA_DATE').size()
# Out:
# DATA_DATE
# 2019-02-10 00:00:00.000     91993
# 2019-02-11 00:00:00.000    121715
# 2019-02-12 00:00:00.000    134392
# 2019-02-13 00:00:00.000    132155
# 2019-02-14 00:00:00.000    114281
# dtype: int64

# %%
for date, group in df.groupby('DATA_DATE'):
    print(date)
    print(group[group['PIC_HX_TOTALPRICE'].notna()].shape[0])
# Out:
# 2019-02-10 00:00:00.000
# 15666
# 2019-02-11 00:00:00.000
# 20643
# 2019-02-12 00:00:00.000
# 22799
# 2019-02-13 00:00:00.000
# 23117
# 2019-02-14 00:00:00.000
# 19681

# %%
df[df['PIC_HX_TOTALPRICE'].notna()].shape[0]
# Out:
# 101906

# %%
df.groupby('DEVICE_ID').size().reset_index(name='count').sort_values(by='count',ascending=False)
# Out:
#                                   DEVICE_ID  count
# 5554   0808A810-141D-471E-AD23-4BA2FE91D87B   1020
# 653                         863447030503899   1009
# 26637                       867788044589994    875
# 29826                       869979036453004    812
# 25227                       866875033490341    612
# 19953                       864665035259568    596
# 10496  44643D1C-97B0-4383-8FFD-502E92458A6A    590
# 6785   1BDF5A3A-53BC-437A-BE35-8CE716CDAE45    542
# 16354                       861608040195099    540
# 38112  E6F7E86B-9A1C-4424-9CFA-1B78DA2F9697    540
# 37947  E4012B9F-63BF-4D81-A4D1-A11A5B6F7BDC    505
# 16208                       861451035639510    498
# 8880                        354765080856701    490
# 14045  77E60B1E-4E42-4255-AD36-DB8CEE1C3948    481
# 39613  FE3102AC-B6A3-4650-9244-955C938159C7    466
# 9684   39137A33-F0C0-43C6-B5C6-84FF7C1FBFF4    463
# 16194                       861438048929632    462
# ...

# %%
df[df['MODELID'].notna()]

# %%
df[df['DEVICE_ID']=='1BDF5A3A-53BC-437A-BE35-8CE716CDAE45']['LOGIN_ACCOUNT'].notna()
# Out:
# 30416    False
# 30417    False
# 30418    False
# 30419    False
# 30420    False
# 30421    False
# 30422    False
# 30423    False
# 30424    False
# 30425    False
# 30426    False
# 30427    False
# 30428    False
# 30429    False
# 30430    False
# 30431    False
# 30432    False
# 30433    False
# 30434    False
# 30435    False
# 30436    False
# 30437    False
# 30438    False
# 30439    False
# 30440    False
# 30441    False
# 30442    False
# 30443    False
# 30444    False
# 30445    False
#          ...
# 30928    False
# 30929    False
# 30930    False
# 30931    False
# 30932    False
# 30933    False
# 30934    False
# 30935    False
# 30936    False
# 30937    False
# 30938    False
# 30939    False
# 30940    False
# 30941    False
# 30942    False
# 30943    False
# 30944    False
# 30945    False
# 30946    False
# 30947    False
# 30948    False
# 30949    False
# 30950    False
# 30951    False
# 30952    False
# 30953    False
# 30954    False
# ...

# %%
df[df['DEVICE_ID']=='1BDF5A3A-53BC-437A-BE35-8CE716CDAE45']['LOGIN_ACCOUNT'].notna()
# Out:
# /Users/michael/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# <ipython-input-30-8a2150429a1b> in <module>()
# ----> 1 df[df[df['DEVICE_ID']=='1BDF5A3A-53BC-437A-BE35-8CE716CDAE45']['LOGIN_ACCOUNT'].notna()]
#
# ~/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2677         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2678             # either boolean or fancy integer index
# -> 2679             return self._getitem_array(key)
#    2680         elif isinstance(key, DataFrame):
#    2681             return self._getitem_frame(key)
#
# ...

# %%
df.ix[94169]['LOGIN_ACCOUNT']
# Out:
# /Users/michael/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# 19951953059.0

# %%
# from pandas.io.json import json_normalize

# %%
# df['content']

# %%
# import json
# def custom(x):
#     try:
#         object=json.loads(x)
#         return (object['roomId'],object['projectType'],object['projectId'])
#     except:
#         return (np.NAN,np.NAN,np.NAN)
    
# (df['roomId'],df['projectType'],df['projectId'])=df['content'].apply(custom)

# %%
# import json
# def custom(df):
#     try:
#         object=json.loads(df['content'])
#         df['roomId']=object.get('roomId',np.NaN)
#         df['projectType']=object.get('projectType',np.NaN)
#         df['modelId']=object.get('modelId',np.NaN)
#         df['projectId']=object.get('projectId',np.ALLOW_THREADSNaN)
#         df['shaiXuan']=object.get('shaiXuan',np.NaN)
#         return df
#     except:
#         df['roomId']=np.NaN
#         df['projectType']=np.NaN
#         df['modelId']=np.NaN
#         df['projectId']=np.NaN
#         df['shaiXuan']=np.NaN
#         return df

# def custom(df):
#     try:
#         object = json.loads(df['CONTENT'])
#         df['ROOMID'] = object.get('roomId', np.NaN)
#         df['PROJECTTYPE'] = object.get('projectType', np.NaN)
#         df['MODELID'] = object.get('modelId', np.NaN)
#         df['PROJECTID'] = object.get('projectId', np.NaN)
#         df['SHAIXUAN'] = object.get('shaiXuan', np.NaN)
#         return df
#     except:
#         df['ROOMID'] = np.NaN
#         df['PROJECTTYPE'] = np.NaN
#         df['MODELID'] = np.NaN
#         df['PROJECTID'] = np.NaN
#         df['SHAIXUAN'] = np.NaN
#         return df
    
# df=df.apply(custom,axis=1)

# %%
df[df['']]

# %%
# df.dropna(subset=['CONTENT'])

# %%
# columns=[ 'PIC_ID','PIC_PRJID','PIC_PRJNAME','PIC_TYPE','PIC_DESC','PIC_TING','PIC_WEI','PIC_CHU','PIC_AREA','PIC_SELL_POINT','PIC_HX_TOTALPRICE' ]
# df2=pd.read_csv('newHouseModel.txt', names=columns,header=None ,dtype={'PIC_ID':object})

# %%
# df2[:10]

# %%
# df.info()

# %%
# df2.info()

# %%
# df_model=df.merge(df2,left_on='MODELID',right_on='PIC_ID',how='left')

# %%
# df_model.dropna(subset=['PIC_PRJID'])

# %%
# room_columes=['room_id','flats','price','totalprice']
# df3=pd.read_csv('newHouseRoom.txt',header=None, names=room_columes, dtype={'room_id':object} ,low_memory=False)

# %%
# df3[:10]

# %%
# df_final=df_model.merge(df3,left_on='ROOMID',right_on='room_id',how='left')

# %%
# df_final.dropna(subset=['CONTENT'])
