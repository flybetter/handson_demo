# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('newHouseLog.csv')

# %%
df
# Out:
#         B_LAT       B_LNG  CHANNEL CITY_NAME CITY_x CITY_y  \
# 0   32.190129  118.419755        1        南京     南京     nj
# 1   32.190129  118.419755        1        南京     南京     nj
# 2   32.190129  118.419755        1        南京     南京     nj
# 3   32.190129  118.419755        1        南京     南京     nj
# 4   32.190129  118.419755        1        南京     南京     nj
# 5   32.190129  118.419755        1        南京     南京     nj
# 6   32.037937  118.917856        1        南京     南京     nj
# 7   32.037937  118.917856        1        南京     南京     nj
# 8   32.037937  118.917856        1        南京     南京     nj
# 9   32.037937  118.917856        1        南京     南京     nj
# 10  32.037937  118.917856        1        南京     南京     nj
# 11  32.037937  118.917856        1        南京     南京     nj
# 12  32.037937  118.917856        1        南京     南京     nj
# 13  32.037937  118.917856        1        南京     南京     nj
# 14  32.037937  118.917856        1        南京     南京     nj
# 15  32.037937  118.917856        1        南京     南京     nj
# 16  32.037937  118.917856        1        南京     南京     nj
# 17  32.037937  118.917856        1        南京     南京     nj
# 18  32.037937  118.917856        1        南京     南京     nj
# 19  32.037937  118.917856        1        南京     南京     nj
# 20  32.037937  118.917856        1        南京     南京     nj
# 21  32.037937  118.917856        1        南京     南京     nj
# 22  32.037937  118.917856        1        南京     南京     nj
# 23  31.962876  118.866496        1        南京     南京     nj
# 24  31.962876  118.866496        1        南京     南京     nj
# 25  31.962876  118.866496        1        南京     南京     nj
# 26  31.962876  118.866496        1        南京     南京     nj
# 27  31.962876  118.866496        1        南京     南京     nj
#
#                                               CONTENT  CONTEXT CONTEXT_ID  \
# 0   {\n  "projectType" : "1",\n  "projectId" : "24...   240781   1-240781
# 1   {\n  "modelId" : "2799236",\n  "projectType" :...   240781   1-240781
# 2   {\n  "modelId" : "2799232",\n  "projectType" :...   240781   1-240781
# 3   {\n  "modelId" : "2799232",\n  "projectType" :...   240781   1-240781
# 4   {\n  "modelId" : "2799236",\n  "projectType" :...   240781   1-240781
# 5   {\n  "projectType" : "1",\n  "projectId" : "24...   240781   1-240781
# 6   {\n  "projectType" : "1",\n  "projectId" : "23...   234015   1-234015
# 7   {\n  "modelId" : "2580869",\n  "projectType" :...   234015   1-234015
# 8   {\n  "roomId" : "6460751",\n  "projectType" : ...   234015   1-234015
# 9   {\n  "modelId" : "2580869",\n  "projectType" :...   234015   1-234015
# 10  {\n  "roomId" : "6460747",\n  "projectType" : ...   234015   1-234015
# 11  {\n  "modelId" : "2580869",\n  "projectType" :...   234015   1-234015
# 12  {\n  "roomId" : "6460749",\n  "projectType" : ...   234015   1-234015
# 13  {\n  "modelId" : "2580869",\n  "projectType" :...   234015   1-234015
# 14  {\n  "projectType" : "1",\n  "projectId" : "23...   234015   1-234015
# 15  {\n  "modelId" : "2699831",\n  "projectType" :...   234015   1-234015
# 16  {\n  "roomId" : "5992961",\n  "projectType" : ...   234015   1-234015
# 17  {\n  "modelId" : "2699831",\n  "projectType" :...   234015   1-234015
# 18  {\n  "roomId" : "5992963",\n  "projectType" : ...   234015   1-234015
# 19  {\n  "modelId" : "2699831",\n  "projectType" :...   234015   1-234015
# 20  {\n  "roomId" : "5992965",\n  "projectType" : ...   234015   1-234015
# 21  {\n  "modelId" : "2699831",\n  "projectType" :...   234015   1-234015
# 22  {\n  "projectType" : "1",\n  "projectId" : "23...   234015   1-234015
# 23  {\n  "projectType" : "1",\n  "projectId" : "23...   238817   1-238817
# 24  {\n  "modelId" : "2564477",\n  "projectType" :...   238817   1-238817
# 25  {\n  "roomId" : "4590511",\n  "projectType" : ...   238817   1-238817
# 26  {\n  "modelId" : "2564477",\n  "projectType" :...   238817   1-238817
# 27  {\n  "projectType" : "1",\n  "projectId" : "23...   238817   1-238817
#
#         DATA_DATE     ...     PRJ_LISTID                         PRJ_LOC  \
# 0   1547769600000     ...         240781               滁州市南谯红琊山路、丰山路西侧地块
# 1   1547769600000     ...         240781               滁州市南谯红琊山路、丰山路西侧地块
# 2   1547769600000     ...         240781               滁州市南谯红琊山路、丰山路西侧地块
# 3   1547769600000     ...         240781               滁州市南谯红琊山路、丰山路西侧地块
# 4   1547769600000     ...         240781               滁州市南谯红琊山路、丰山路西侧地块
# 5   1547769600000     ...         240781               滁州市南谯红琊山路、丰山路西侧地块
# 6   1547769600000     ...         234015                    麒麟街道运粮河东路99号
# 7   1547769600000     ...         234015                    麒麟街道运粮河东路99号
# 8   1547769600000     ...         234015                    麒麟街道运粮河东路99号
# 9   1547769600000     ...         234015                    麒麟街道运粮河东路99号
# 10  1547769600000     ...         234015                    麒麟街道运粮河东路99号
# 11  1547769600000     ...         234015                    麒麟街道运粮河东路99号
# 12  1547769600000     ...         234015                    麒麟街道运粮河东路99号
# 13  1547769600000     ...         234015                    麒麟街道运粮河东路99号
# 14  1547769600000     ...         234015                    麒麟街道运粮河东路99号
# 15  1547769600000     ...         234015                    麒麟街道运粮河东路99号
# 16  1547769600000     ...         234015                    麒麟街道运粮河东路99号
# 17  1547769600000     ...         234015                    麒麟街道运粮河东路99号
# 18  1547769600000     ...         234015                    麒麟街道运粮河东路99号
# 19  1547769600000     ...         234015                    麒麟街道运粮河东路99号
# 20  1547769600000     ...         234015                    麒麟街道运粮河东路99号
# 21  1547769600000     ...         234015                    麒麟街道运粮河东路99号
# 22  1547769600000     ...         234015                    麒麟街道运粮河东路99号
# 23  1547769600000     ...         238817  东山街道天印大道837号(东山街道上元大街与天印大道交汇处)
# 24  1547769600000     ...         238817  东山街道天印大道837号(东山街道上元大街与天印大道交汇处)
# 25  1547769600000     ...         238817  东山街道天印大道837号(东山街道上元大街与天印大道交汇处)
# 26  1547769600000     ...         238817  东山街道天印大道837号(东山街道上元大街与天印大道交汇处)
# 27  1547769600000     ...         238817  东山街道天印大道837号(东山街道上元大街与天印大道交汇处)
#
#     PRJ_VIEWS  PROJECTID  PROJECTTYPE     ROOMID    ROOM_ID  SHAIXUAN  \
# 0        9480     240781            1        NaN        NaN       NaN
# 1        9480     240781            1        NaN        NaN       NaN
# 2        9480     240781            1        NaN        NaN       NaN
# 3        9480     240781            1        NaN        NaN       NaN
# 4        9480     240781            1        NaN        NaN       NaN
# 5        9480     240781            1        NaN        NaN       NaN
# 6       66212     234015            1        NaN        NaN       NaN
# 7       66212     234015            1        NaN        NaN       NaN
# 8       66212     234015            1  6460751.0  6460751.0       NaN
# 9       66212     234015            1        NaN        NaN       NaN
# 10      66212     234015            1  6460747.0  6460747.0       NaN
# 11      66212     234015            1        NaN        NaN       NaN
# 12      66212     234015            1  6460749.0  6460749.0       NaN
# 13      66212     234015            1        NaN        NaN       NaN
# 14      66212     234015            1        NaN        NaN       NaN
# 15      66212     234015            1        NaN        NaN       NaN
# 16      66212     234015            1  5992961.0  5992961.0       NaN
# 17      66212     234015            1        NaN        NaN       NaN
# 18      66212     234015            1  5992963.0  5992963.0       NaN
# 19      66212     234015            1        NaN        NaN       NaN
# 20      66212     234015            1  5992965.0  5992965.0       NaN
# 21      66212     234015            1        NaN        NaN       NaN
# 22      66212     234015            1        NaN        NaN       NaN
# 23      50581     238817            1        NaN        NaN       NaN
# 24      50581     238817            1        NaN        NaN       NaN
# 25      50581     238817            1  4590511.0  4590511.0       NaN
# 26      50581     238817            1        NaN        NaN       NaN
# 27      50581     238817            1        NaN        NaN       NaN
#
#                  START_TIME  TOTALPRICE
# 0   2019-01-18 04:21:59.059         NaN
# 1   2019-01-18 04:22:03.003         NaN
# 2   2019-01-18 04:22:05.005         NaN
# 3   2019-01-18 04:22:07.007         NaN
# 4   2019-01-18 04:22:08.008         NaN
# 5   2019-01-18 04:22:09.009         NaN
# 6   2019-01-18 04:22:55.055         NaN
# 7   2019-01-18 04:23:00.000         NaN
# 8   2019-01-18 04:23:03.003      345.71
# 9   2019-01-18 04:23:05.005         NaN
# 10  2019-01-18 04:23:08.008      358.59
# 11  2019-01-18 04:23:11.011         NaN
# 12  2019-01-18 04:23:12.012      356.02
# 13  2019-01-18 04:23:13.013         NaN
# 14  2019-01-18 04:23:14.014         NaN
# 15  2019-01-18 04:23:16.016         NaN
# 16  2019-01-18 04:23:21.021      331.98
# 17  2019-01-18 04:23:23.023         NaN
# 18  2019-01-18 04:23:24.024      330.81
# 19  2019-01-18 04:23:26.026         NaN
# 20  2019-01-18 04:23:27.027      324.95
# 21  2019-01-18 04:23:28.028         NaN
# 22  2019-01-18 04:23:30.030         NaN
# 23  2019-01-18 04:23:34.034         NaN
# 24  2019-01-18 04:23:39.039         NaN
# 25  2019-01-18 04:23:42.042      251.26
# 26  2019-01-18 04:23:45.045         NaN
# 27  2019-01-18 04:23:48.048         NaN
#
# [28 rows x 42 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 42 columns):
# B_LAT                28 non-null float64
# B_LNG                28 non-null float64
# CHANNEL              28 non-null int64
# CITY_NAME            28 non-null object
# CITY_x               28 non-null object
# CITY_y               28 non-null object
# CONTENT              28 non-null object
# CONTEXT              28 non-null int64
# CONTEXT_ID           28 non-null object
# DATA_DATE            28 non-null int64
# DEVICE_ID            28 non-null object
# END_TIME             28 non-null object
# FLATS                7 non-null float64
# LOGIN_ACCOUNT        28 non-null int64
# MODELID              14 non-null float64
# OBJECT_ID            0 non-null float64
# PIC_AREA             14 non-null float64
# PIC_CHU              14 non-null float64
# PIC_DESC             14 non-null object
# PIC_HX_TOTALPRICE    10 non-null float64
# PIC_ID               14 non-null float64
# PIC_PRJID            14 non-null float64
# PIC_PRJNAME          14 non-null object
# PIC_SELL_POINT       14 non-null object
# PIC_TING             14 non-null float64
# PIC_TYPE             14 non-null float64
# PIC_WEI              14 non-null float64
# PRICE                7 non-null float64
# PRICE_AVG            28 non-null int64
# PRICE_SHOW           28 non-null object
# PRJ_DECORATE         28 non-null object
# PRJ_ITEMNAME         28 non-null object
# PRJ_LISTID           28 non-null int64
# PRJ_LOC              28 non-null object
# PRJ_VIEWS            28 non-null int64
# PROJECTID            28 non-null int64
# PROJECTTYPE          28 non-null int64
# ROOMID               7 non-null float64
# ROOM_ID              7 non-null float64
# SHAIXUAN             0 non-null float64
# START_TIME           28 non-null object
# TOTALPRICE           7 non-null float64
# dtypes: float64(18), int64(9), object(15)
# memory usage: 9.3+ KB

# %%
df[['CONTEXT_ID','DEVICE_ID','LOGIN_ACCOUNT','CONTENT','ROOMID','MODELID']]
# Out:
#    CONTEXT_ID                             DEVICE_ID  LOGIN_ACCOUNT  \
# 0    1-240781  A5B9DA9F-40C6-4DE4-9539-3A288CE6B614    18118849310
# 1    1-240781  A5B9DA9F-40C6-4DE4-9539-3A288CE6B614    18118849310
# 2    1-240781  A5B9DA9F-40C6-4DE4-9539-3A288CE6B614    18118849310
# 3    1-240781  A5B9DA9F-40C6-4DE4-9539-3A288CE6B614    18118849310
# 4    1-240781  A5B9DA9F-40C6-4DE4-9539-3A288CE6B614    18118849310
# 5    1-240781  A5B9DA9F-40C6-4DE4-9539-3A288CE6B614    18118849310
# 6    1-234015  A5B9DA9F-40C6-4DE4-9539-3A288CE6B614    18118849310
# 7    1-234015  A5B9DA9F-40C6-4DE4-9539-3A288CE6B614    18118849310
# 8    1-234015  A5B9DA9F-40C6-4DE4-9539-3A288CE6B614    18118849310
# 9    1-234015  A5B9DA9F-40C6-4DE4-9539-3A288CE6B614    18118849310
# 10   1-234015  A5B9DA9F-40C6-4DE4-9539-3A288CE6B614    18118849310
# 11   1-234015  A5B9DA9F-40C6-4DE4-9539-3A288CE6B614    18118849310
# 12   1-234015  A5B9DA9F-40C6-4DE4-9539-3A288CE6B614    18118849310
# 13   1-234015  A5B9DA9F-40C6-4DE4-9539-3A288CE6B614    18118849310
# 14   1-234015  A5B9DA9F-40C6-4DE4-9539-3A288CE6B614    18118849310
# 15   1-234015  A5B9DA9F-40C6-4DE4-9539-3A288CE6B614    18118849310
# 16   1-234015  A5B9DA9F-40C6-4DE4-9539-3A288CE6B614    18118849310
# 17   1-234015  A5B9DA9F-40C6-4DE4-9539-3A288CE6B614    18118849310
# 18   1-234015  A5B9DA9F-40C6-4DE4-9539-3A288CE6B614    18118849310
# 19   1-234015  A5B9DA9F-40C6-4DE4-9539-3A288CE6B614    18118849310
# 20   1-234015  A5B9DA9F-40C6-4DE4-9539-3A288CE6B614    18118849310
# 21   1-234015  A5B9DA9F-40C6-4DE4-9539-3A288CE6B614    18118849310
# 22   1-234015  A5B9DA9F-40C6-4DE4-9539-3A288CE6B614    18118849310
# 23   1-238817  A5B9DA9F-40C6-4DE4-9539-3A288CE6B614    18118849310
# 24   1-238817  A5B9DA9F-40C6-4DE4-9539-3A288CE6B614    18118849310
# 25   1-238817  A5B9DA9F-40C6-4DE4-9539-3A288CE6B614    18118849310
# 26   1-238817  A5B9DA9F-40C6-4DE4-9539-3A288CE6B614    18118849310
# 27   1-238817  A5B9DA9F-40C6-4DE4-9539-3A288CE6B614    18118849310
#
#                                               CONTENT     ROOMID    MODELID
# 0   {\n  "projectType" : "1",\n  "projectId" : "24...        NaN        NaN
# 1   {\n  "modelId" : "2799236",\n  "projectType" :...        NaN  2799236.0
# 2   {\n  "modelId" : "2799232",\n  "projectType" :...        NaN  2799232.0
# 3   {\n  "modelId" : "2799232",\n  "projectType" :...        NaN  2799232.0
# 4   {\n  "modelId" : "2799236",\n  "projectType" :...        NaN  2799236.0
# 5   {\n  "projectType" : "1",\n  "projectId" : "24...        NaN        NaN
# 6   {\n  "projectType" : "1",\n  "projectId" : "23...        NaN        NaN
# 7   {\n  "modelId" : "2580869",\n  "projectType" :...        NaN  2580869.0
# 8   {\n  "roomId" : "6460751",\n  "projectType" : ...  6460751.0        NaN
# 9   {\n  "modelId" : "2580869",\n  "projectType" :...        NaN  2580869.0
# 10  {\n  "roomId" : "6460747",\n  "projectType" : ...  6460747.0        NaN
# 11  {\n  "modelId" : "2580869",\n  "projectType" :...        NaN  2580869.0
# 12  {\n  "roomId" : "6460749",\n  "projectType" : ...  6460749.0        NaN
# 13  {\n  "modelId" : "2580869",\n  "projectType" :...        NaN  2580869.0
# 14  {\n  "projectType" : "1",\n  "projectId" : "23...        NaN        NaN
# 15  {\n  "modelId" : "2699831",\n  "projectType" :...        NaN  2699831.0
# 16  {\n  "roomId" : "5992961",\n  "projectType" : ...  5992961.0        NaN
# 17  {\n  "modelId" : "2699831",\n  "projectType" :...        NaN  2699831.0
# 18  {\n  "roomId" : "5992963",\n  "projectType" : ...  5992963.0        NaN
# 19  {\n  "modelId" : "2699831",\n  "projectType" :...        NaN  2699831.0
# 20  {\n  "roomId" : "5992965",\n  "projectType" : ...  5992965.0        NaN
# 21  {\n  "modelId" : "2699831",\n  "projectType" :...        NaN  2699831.0
# 22  {\n  "projectType" : "1",\n  "projectId" : "23...        NaN        NaN
# 23  {\n  "projectType" : "1",\n  "projectId" : "23...        NaN        NaN
# 24  {\n  "modelId" : "2564477",\n  "projectType" :...        NaN  2564477.0
# 25  {\n  "roomId" : "4590511",\n  "projectType" : ...  4590511.0        NaN
# 26  {\n  "modelId" : "2564477",\n  "projectType" :...        NaN  2564477.0
# 27  {\n  "projectType" : "1",\n  "projectId" : "23...        NaN        NaN

# %%
df[['CONTEXT_ID','DEVICE_ID','LOGIN_ACCOUNT','CONTENT','ROOMID','MODELID','PIC_ID', 'PIC_PRJID', 'PIC_PRJNAME', 'PIC_TYPE', 'PIC_DESC', 'PIC_TING', 'PIC_WEI', 'PIC_CHU',
                   'PIC_AREA', 'PIC_SELL_POINT', 'PIC_HX_TOTALPRICE','FLATS']]
# Out:
#    CONTEXT_ID                             DEVICE_ID  LOGIN_ACCOUNT  \
# 0    1-240781  A5B9DA9F-40C6-4DE4-9539-3A288CE6B614    18118849310
# 1    1-240781  A5B9DA9F-40C6-4DE4-9539-3A288CE6B614    18118849310
# 2    1-240781  A5B9DA9F-40C6-4DE4-9539-3A288CE6B614    18118849310
# 3    1-240781  A5B9DA9F-40C6-4DE4-9539-3A288CE6B614    18118849310
# 4    1-240781  A5B9DA9F-40C6-4DE4-9539-3A288CE6B614    18118849310
# 5    1-240781  A5B9DA9F-40C6-4DE4-9539-3A288CE6B614    18118849310
# 6    1-234015  A5B9DA9F-40C6-4DE4-9539-3A288CE6B614    18118849310
# 7    1-234015  A5B9DA9F-40C6-4DE4-9539-3A288CE6B614    18118849310
# 8    1-234015  A5B9DA9F-40C6-4DE4-9539-3A288CE6B614    18118849310
# 9    1-234015  A5B9DA9F-40C6-4DE4-9539-3A288CE6B614    18118849310
# 10   1-234015  A5B9DA9F-40C6-4DE4-9539-3A288CE6B614    18118849310
# 11   1-234015  A5B9DA9F-40C6-4DE4-9539-3A288CE6B614    18118849310
# 12   1-234015  A5B9DA9F-40C6-4DE4-9539-3A288CE6B614    18118849310
# 13   1-234015  A5B9DA9F-40C6-4DE4-9539-3A288CE6B614    18118849310
# 14   1-234015  A5B9DA9F-40C6-4DE4-9539-3A288CE6B614    18118849310
# 15   1-234015  A5B9DA9F-40C6-4DE4-9539-3A288CE6B614    18118849310
# 16   1-234015  A5B9DA9F-40C6-4DE4-9539-3A288CE6B614    18118849310
# 17   1-234015  A5B9DA9F-40C6-4DE4-9539-3A288CE6B614    18118849310
# 18   1-234015  A5B9DA9F-40C6-4DE4-9539-3A288CE6B614    18118849310
# 19   1-234015  A5B9DA9F-40C6-4DE4-9539-3A288CE6B614    18118849310
# 20   1-234015  A5B9DA9F-40C6-4DE4-9539-3A288CE6B614    18118849310
# 21   1-234015  A5B9DA9F-40C6-4DE4-9539-3A288CE6B614    18118849310
# 22   1-234015  A5B9DA9F-40C6-4DE4-9539-3A288CE6B614    18118849310
# 23   1-238817  A5B9DA9F-40C6-4DE4-9539-3A288CE6B614    18118849310
# 24   1-238817  A5B9DA9F-40C6-4DE4-9539-3A288CE6B614    18118849310
# 25   1-238817  A5B9DA9F-40C6-4DE4-9539-3A288CE6B614    18118849310
# 26   1-238817  A5B9DA9F-40C6-4DE4-9539-3A288CE6B614    18118849310
# 27   1-238817  A5B9DA9F-40C6-4DE4-9539-3A288CE6B614    18118849310
#
#                                               CONTENT     ROOMID    MODELID  \
# 0   {\n  "projectType" : "1",\n  "projectId" : "24...        NaN        NaN
# 1   {\n  "modelId" : "2799236",\n  "projectType" :...        NaN  2799236.0
# 2   {\n  "modelId" : "2799232",\n  "projectType" :...        NaN  2799232.0
# 3   {\n  "modelId" : "2799232",\n  "projectType" :...        NaN  2799232.0
# 4   {\n  "modelId" : "2799236",\n  "projectType" :...        NaN  2799236.0
# 5   {\n  "projectType" : "1",\n  "projectId" : "24...        NaN        NaN
# 6   {\n  "projectType" : "1",\n  "projectId" : "23...        NaN        NaN
# 7   {\n  "modelId" : "2580869",\n  "projectType" :...        NaN  2580869.0
# 8   {\n  "roomId" : "6460751",\n  "projectType" : ...  6460751.0        NaN
# 9   {\n  "modelId" : "2580869",\n  "projectType" :...        NaN  2580869.0
# 10  {\n  "roomId" : "6460747",\n  "projectType" : ...  6460747.0        NaN
# 11  {\n  "modelId" : "2580869",\n  "projectType" :...        NaN  2580869.0
# 12  {\n  "roomId" : "6460749",\n  "projectType" : ...  6460749.0        NaN
# 13  {\n  "modelId" : "2580869",\n  "projectType" :...        NaN  2580869.0
# 14  {\n  "projectType" : "1",\n  "projectId" : "23...        NaN        NaN
# 15  {\n  "modelId" : "2699831",\n  "projectType" :...        NaN  2699831.0
# 16  {\n  "roomId" : "5992961",\n  "projectType" : ...  5992961.0        NaN
# 17  {\n  "modelId" : "2699831",\n  "projectType" :...        NaN  2699831.0
# 18  {\n  "roomId" : "5992963",\n  "projectType" : ...  5992963.0        NaN
# 19  {\n  "modelId" : "2699831",\n  "projectType" :...        NaN  2699831.0
# 20  {\n  "roomId" : "5992965",\n  "projectType" : ...  5992965.0        NaN
# 21  {\n  "modelId" : "2699831",\n  "projectType" :...        NaN  2699831.0
# 22  {\n  "projectType" : "1",\n  "projectId" : "23...        NaN        NaN
# 23  {\n  "projectType" : "1",\n  "projectId" : "23...        NaN        NaN
# 24  {\n  "modelId" : "2564477",\n  "projectType" :...        NaN  2564477.0
# 25  {\n  "roomId" : "4590511",\n  "projectType" : ...  4590511.0        NaN
# 26  {\n  "modelId" : "2564477",\n  "projectType" :...        NaN  2564477.0
# 27  {\n  "projectType" : "1",\n  "projectId" : "23...        NaN        NaN
#
#        PIC_ID  PIC_PRJID PIC_PRJNAME  PIC_TYPE                 PIC_DESC  \
# 0         NaN        NaN         NaN       NaN                      NaN
# 1   2799236.0   240781.0     碧桂园十里春风      10.0  碧桂园十里春风YJ115T-B户型图约122㎡
# 2   2799232.0   240781.0     碧桂园十里春风      11.0    碧桂园十里春风YJ140T户型图约143㎡
# 3   2799232.0   240781.0     碧桂园十里春风      11.0    碧桂园十里春风YJ140T户型图约143㎡
# 4   2799236.0   240781.0     碧桂园十里春风      10.0  碧桂园十里春风YJ115T-B户型图约122㎡
# 5         NaN        NaN         NaN       NaN                      NaN
# 6         NaN        NaN         NaN       NaN                      NaN
# 7   2580869.0   234015.0          熙悦      10.0               熙悦E户型图128㎡
# 8         NaN        NaN         NaN       NaN                      NaN
# 9   2580869.0   234015.0          熙悦      10.0               熙悦E户型图128㎡
# 10        NaN        NaN         NaN       NaN                      NaN
# 11  2580869.0   234015.0          熙悦      10.0               熙悦E户型图128㎡
# 12        NaN        NaN         NaN       NaN                      NaN
# 13  2580869.0   234015.0          熙悦      10.0               熙悦E户型图128㎡
# 14        NaN        NaN         NaN       NaN                      NaN
# 15  2699831.0   234015.0          熙悦      10.0               熙悦D2户型117㎡
# 16        NaN        NaN         NaN       NaN                      NaN
# 17  2699831.0   234015.0          熙悦      10.0               熙悦D2户型117㎡
# 18        NaN        NaN         NaN       NaN                      NaN
# 19  2699831.0   234015.0          熙悦      10.0               熙悦D2户型117㎡
# 20        NaN        NaN         NaN       NaN                      NaN
# 21  2699831.0   234015.0          熙悦      10.0               熙悦D2户型117㎡
# 22        NaN        NaN         NaN       NaN                      NaN
# 23        NaN        NaN         NaN       NaN                      NaN
# 24  2564477.0   238817.0      万科金域国际       9.0             万科金域国际90㎡户型图
# 25        NaN        NaN         NaN       NaN                      NaN
# 26  2564477.0   238817.0      万科金域国际       9.0             万科金域国际90㎡户型图
# 27        NaN        NaN         NaN       NaN                      NaN
#
#     PIC_TING  PIC_WEI  PIC_CHU  PIC_AREA PIC_SELL_POINT  PIC_HX_TOTALPRICE  \
# 0        NaN      NaN      NaN       NaN            NaN                NaN
# 1        2.0      2.0      1.0       0.0     三开间朝南 南北通透                NaN
# 2        2.0      2.0      1.0     143.0     四开间朝南 南北通透                NaN
# 3        2.0      2.0      1.0     143.0     四开间朝南 南北通透                NaN
# 4        2.0      2.0      1.0       0.0     三开间朝南 南北通透                NaN
# 5        NaN      NaN      NaN       NaN            NaN                NaN
# 6        NaN      NaN      NaN       NaN            NaN                NaN
# 7        2.0      2.0      1.0     128.0    三开间并排朝南，采光好             374.68
# 8        NaN      NaN      NaN       NaN            NaN                NaN
# 9        2.0      2.0      1.0     128.0    三开间并排朝南，采光好             374.68
# 10       NaN      NaN      NaN       NaN            NaN                NaN
# 11       2.0      2.0      1.0     128.0    三开间并排朝南，采光好             374.68
# 12       NaN      NaN      NaN       NaN            NaN                NaN
# 13       2.0      2.0      1.0     128.0    三开间并排朝南，采光好             374.68
# 14       NaN      NaN      NaN       NaN            NaN                NaN
# 15       2.0      2.0      1.0     117.0     户型方正、三开间朝南             338.00
# 16       NaN      NaN      NaN       NaN            NaN                NaN
# 17       2.0      2.0      1.0     117.0     户型方正、三开间朝南             338.00
# 18       NaN      NaN      NaN       NaN            NaN                NaN
# 19       2.0      2.0      1.0     117.0     户型方正、三开间朝南             338.00
# 20       NaN      NaN      NaN       NaN            NaN                NaN
# 21       2.0      2.0      1.0     117.0     户型方正、三开间朝南             338.00
# 22       NaN      NaN      NaN       NaN            NaN                NaN
# 23       NaN      NaN      NaN       NaN            NaN                NaN
# 24       2.0      1.0      1.0      90.0      户型方正 南北通透             254.68
# 25       NaN      NaN      NaN       NaN            NaN                NaN
# 26       2.0      1.0      1.0      90.0      户型方正 南北通透             254.68
# 27       NaN      NaN      NaN       NaN            NaN                NaN
#
#     FLATS
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     NaN
# 7     NaN
# 8     1.0
# 9     NaN
# 10    1.0
# 11    NaN
# 12    1.0
# 13    NaN
# 14    NaN
# 15    NaN
# 16    1.0
# 17    NaN
# 18    1.0
# 19    NaN
# 20    1.0
# 21    NaN
# 22    NaN
# 23    NaN
# 24    NaN
# 25    2.0
# 26    NaN
# 27    NaN
